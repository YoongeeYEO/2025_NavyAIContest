# %%
# ===============================
# 0-1. 필수 라이브러리 설치
# ===============================
# !pip install lightgbm catboost shap optuna geopandas shapely pyproj fiona pyarrow --quiet

# ===============================
# 0-2. Google Drive 마운트
# ===============================
from google.colab import drive
drive.mount('/content/drive')
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 24.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.6/386.6 kB 32.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 110.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 19.6 MB/s eta 0:00:00
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# ===============================
# 1. 모듈 임포트
# ===============================
import os, re, glob, warnings, joblib
import numpy as np
import pandas as pd
import geopandas as gpd
from datetime import datetime, timedelta
from shapely.geometry import Polygon
from shapely import wkt

from sklearn.preprocessing    import RobustScaler
from sklearn.model_selection   import StratifiedKFold
from sklearn.metrics           import accuracy_score
from sklearn.ensemble          import StackingClassifier, IsolationForest
from sklearn.feature_selection import VarianceThreshold

import optuna
from lightgbm import LGBMClassifier, early_stopping as lgb_es, log_evaluation as lgb_log
from xgboost  import XGBClassifier
from catboost import CatBoostClassifier

warnings.filterwarnings('ignore')
SEED    = 42
NTRIAL  = 100
NSPLIT  = 5

# %%
# ===============================
# 2. 상수 정의
# ===============================
DATA_DIR = '/content/drive/MyDrive/25년 해군 AI 경진대회/dataset/의심선박 훈련용 데이터 셋'
ZONE_DIR = '/content/drive/MyDrive/25년 해군 AI 경진대회/dataset/구역 데이터'
OUT_DIR  = '/content/drive/MyDrive/25년 해군 AI 경진대회/model_result'
os.makedirs(OUT_DIR, exist_ok=True)

# %%
# ===============================
# 3. 구역 데이터 로드 함수
# ===============================
def detect_wkt_col(df):
    for c in df.columns:
        if df[c].dtype == 'object':
            sample = df[c].dropna().astype(str).str.upper()
            if sample.str.startswith(('POLYGON','MULTIPOLYGON','LINESTRING')).any():
                return c
    return None

def load_zones(zone_dir):
    files = glob.glob(os.path.join(zone_dir, '*'))
    gdfs  = []
    for fp in files:
        ext = os.path.splitext(fp)[1].lower()
        try:
            if ext in ['.shp','.geojson','.json','.gpkg','.kml']:
                g = gpd.read_file(fp).to_crs('EPSG:4326')
            elif ext=='.csv':
                df = pd.read_csv(fp)
                wcol = detect_wkt_col(df)
                if wcol:
                    df['geometry'] = df[wcol].apply(wkt.loads)
                    g = gpd.GeoDataFrame(df, geometry='geometry', crs='EPSG:4326')
                else:
                    lon = [c for c in df.columns if c.lower()=='lon'][0]
                    lat = [c for c in df.columns if c.lower()=='lat'][0]
                    gid = [c for c in df.columns if c not in [lon,lat]][0]
                    df['_gid_'] = df[gid]
                    gb = df.groupby('_gid_')
                    polys = (gb.apply(lambda g: Polygon(list(zip(g[lon], g[lat]))))
                            .reset_index(name='geometry'))
                    g = gpd.GeoDataFrame(polys, geometry='geometry', crs='EPSG:4326')
            else:
                continue
            g['zone_type'] = re.sub(r'\.\w+|area_','',os.path.basename(fp),flags=re.I)
            gdfs.append(g)
        except Exception as e:
            print(f"[Warn] {fp} : {e}")
    if not gdfs:
        raise RuntimeError("구역 데이터를 찾을 수 없습니다.")
    zones = pd.concat(gdfs, ignore_index=True)
    print('Zone types:', zones['zone_type'].unique())
    return zones

zones_gdf = load_zones(ZONE_DIR)

# 영역별 플래그 네이밍
ANCHOR_ZONE        = 'Near_Sea'
SPECIAL_ZONE       = 'Special_restrict_zone_poly'
NAVY_TRAIN_ZONE    = 'Navy_train'
CABLE_ZONE         = 'Sea_cable_lv1_poly'
NO_ENTRY_ZONE      = 'Restrict_zone'
# Out:
# Zone types: ['Navy_train' 'Near_Sea' 'Restrict_zone' 'Sea_cable_lv1_poly'
#  'Special_restrict_zone_poly' 'Target_Area']

# %%
# ===============================
# 4. AIS 집계·피처 엔지니어링
# ===============================
def find_col(df, patterns, required=True):
    def norm(s): return re.sub(r'[\s_\-]','',s.lower())
    pats = [norm(p) for p in patterns]
    for c in df.columns:
        cn = norm(c)
        if any(cn==p or cn.startswith(p) or p in cn for p in pats):
            return c
    if required: raise KeyError(f"필수 컬럼 {patterns} 를 찾을 수 없습니다: {df.columns.tolist()}")
    return None

def aggregate_ais(df):
    df = df.copy()
    df.rename(columns={
        find_col(df,['basedatetime','timestamp','datetime','time']):'Time',
        find_col(df,['latitude','lat']):'Latitude',
        find_col(df,['longitude','lon']):'Longitude',
        find_col(df,['sog','speed']):'SOG',
        find_col(df,['cog','course']):'COG',
        find_col(df,['mmsi']):'MMSI'
    }, inplace=True)
    df['Time'] = pd.to_datetime(df['Time'], errors='coerce')
    df.dropna(subset=['Time','Latitude','Longitude'], inplace=True)
    df.sort_values(['MMSI','Time'], inplace=True)
    gdf = gpd.GeoDataFrame(df,
            geometry=gpd.points_from_xy(df.Longitude, df.Latitude),
            crs='EPSG:4326')
    pts = gpd.sjoin(gdf, zones_gdf[['zone_type','geometry']],
                   how='left', predicate='within')
    # zone flag 추가
    for zt in zones_gdf['zone_type'].unique():
        pts[f'{zt}_flag'] = (pts['zone_type']==zt).astype(int)
    pts.drop(columns=['index_right','zone_type','geometry'], inplace=True)

    def _agg(g):
        times = g['Time'].values
        gaps = np.diff(times).astype('timedelta64[s]').astype(float)
        gaps = np.insert(gaps, 0, 1.0)  # 첫 포인트는 1초
        dur  = gaps.copy()
        dist = []
        # 거리 계산
        lat = np.radians(g['Latitude']); lon = np.radians(g['Longitude'])
        for i in range(1,len(g)):
            dlat = lat.iloc[i]-lat.iloc[i-1]
            dlon = lon.iloc[i]-lon.iloc[i-1]
            a = np.sin(dlat/2)**2 + np.cos(lat.iloc[i])*np.cos(lat.iloc[i-1])*np.sin(dlon/2)**2
            dist.append(2*6371*np.arcsin(np.sqrt(a)))
        dist = [0.0] + dist

        cog_diff = np.abs(np.mod(g['COG'].diff().fillna(0)+180,360)-180)
        acc = g['SOG'].diff().fillna(0) / gaps

        res = {
            'num_pts':len(g),
            'traj_dur': sum(gaps),
            'mean_sog': g['SOG'].mean(),
            'std_sog':  g['SOG'].std(),
            'max_sog':  g['SOG'].max(),
            'min_sog':  g['SOG'].min(),
            'median_sog': g['SOG'].median(),
            'sog_iqr': g['SOG'].quantile(0.75)-g['SOG'].quantile(0.25),
            'mean_cog_diff': cog_diff.mean(),
            'std_cog_diff':  cog_diff.std(),
            'total_dist': sum(dist),
            'mean_acc':   acc.mean(),
            'max_acc':    acc.max(),
            'lowspd_out_anchor_sec':
                ((g['SOG']<=5)&(g[f'{ANCHOR_ZONE}_flag']==0)).dot(dur),
            'nomove_out_anchor_sec':
                ((np.array(dist)<0.05)&(g[f'{ANCHOR_ZONE}_flag']==0)).dot(dur),
            'ais_off_cnt_out_anchor':
                ((gaps>1800)&(g[f'{ANCHOR_ZONE}_flag']==0)).sum(),
            'restrict_train_sec':
                ((g[[f'{SPECIAL_ZONE}_flag',f'{NAVY_TRAIN_ZONE}_flag']].max(axis=1)==1)).dot(dur),
            'sharp_turn_cnt': ((cog_diff>=90)&(g[f'{ANCHOR_ZONE}_flag']==0)).sum(),
            'cable_lowspd_sec':
                ((g[f'{CABLE_ZONE}_flag']==1)&(g['SOG']<=5)).dot(dur),
            'no_entry_flag': int((g[f'{NO_ENTRY_ZONE}_flag']==1).any())
        }
        # zone presence 플래그 추가
        for zt in zones_gdf['zone_type'].unique():
            res[f'{zt}_flag'] = g[f'{zt}_flag'].max()
        return pd.Series(res)

    agg = pts.groupby('MMSI', group_keys=False).apply(_agg).reset_index()
    # 레이블 병합
    if 'result' in df.columns:
        agg = agg.merge(df[['MMSI','result']].drop_duplicates('MMSI'),
                        on='MMSI', how='left')
    return agg

# 손기능 기반 rule_score
def rule_score(r):
    score=0
    if (r['lowspd_out_anchor_sec']>=3600)|(r['nomove_out_anchor_sec']>=3600): score+=.20
    if r['ais_off_cnt_out_anchor']>=3:      score+=.15
    if r['restrict_train_sec']>=3600:       score+=.20
    if r['sharp_turn_cnt']>=1:              score+=.15
    if r['cable_lowspd_sec']>=600:          score+=.15
    if r['no_entry_flag']==1:               score+=.15
    return score*100

# 데이터셋 빌드
def build_dataset(file_list):
    raw = pd.concat([pd.read_csv(f) for f in file_list], ignore_index=True)
    df  = aggregate_ais(raw)
    df['rule_score'] = df.apply(rule_score, axis=1)
    df['target']     = df['result'].map({'TRUE':1,'True':1,True:1,1:1,
                                        'FALSE':0,'False':0,False:0,0:0})
    # 무한대 제거
    num = df.select_dtypes('number').columns
    df[num] = df[num].replace([np.inf,-np.inf], np.nan)
    return df

# %%
# ===============================
# 5. 학습/검증용 데이터 준비
# ===============================
# 날짜별 파일 분할(마지막 92일 학습, 이전 검증)
csv_files   = sorted(glob.glob(os.path.join(DATA_DIR,'*.csv')))
get_date    = lambda f: datetime.strptime(re.search(r'(\d{8})',os.path.basename(f)).group(1),'%Y%m%d')
file_dates  = sorted([(f,get_date(f)) for f in csv_files], key=lambda x:x[1])
last_date   = file_dates[-1][1]
train_files = [f for f,d in file_dates if d>= last_date-timedelta(days=92)]
val_files   = [f for f,d in file_dates if d<  last_date-timedelta(days=92)]

print('Train:', len(train_files), train_files[0][-12:-4],'~',train_files[-1][-12:-4])
print('Val  :', len(val_files),   val_files[0][-12:-4],'~',val_files[-1][-12:-4])

print('⏳ Build Train'); train_df = build_dataset(train_files)
print('⏳ Build Val  '); val_df   = build_dataset(val_files)
print('Shapes:', train_df.shape, val_df.shape)

# 피처·레이블 분리
feat_cols = [c for c in train_df.columns if c not in ('MMSI','result','target')]
X_tr = train_df[feat_cols].values; y_tr = train_df['target'].astype(int).values
X_va = val_df[feat_cols].values; y_va = val_df['target'].astype(int).values
# Out:
# Train: 93 20240229 ~ 20240531
# Val  : 273 20230601 ~ 20240228
# ⏳ Build Train
# ⏳ Build Val
# Shapes: (30329, 30) (44155, 30)

# %%
# ===============================
# 6. 이상치 제거 & 특징 선택
# ===============================
# 6-1) 이상치 제거
iso = IsolationForest(contamination=0.01, random_state=SEED)
mask = iso.fit_predict(X_tr) == 1
X_tr, y_tr = X_tr[mask], y_tr[mask]

# 6-2) 스케일링 → 분산영 특성 제거
scaler = RobustScaler()
X_tr = scaler.fit_transform(X_tr)
X_va = scaler.transform(X_va)

vt = VarianceThreshold(threshold=0.0)
X_tr = vt.fit_transform(X_tr)
X_va = vt.transform(X_va)

# 선택된 피처 이름 리스트
selected_feats = [feat_cols[i] for i, keep in enumerate(vt.get_support()) if keep]
print(f"Selected {len(selected_feats)}/{len(feat_cols)} features")
# Out:
# Selected 23/27 features

# %%
# ===============================
# 7. 하이퍼파라미터 튜닝
# ===============================
skf = StratifiedKFold(n_splits=NSPLIT, shuffle=True, random_state=SEED)
pos_weight = (y_tr==0).sum() / (y_tr==1).sum()

def tune_lgb(trial):
    params = {
        'objective':'binary','metric':'binary_logloss','seed':SEED,'is_unbalance':True,
        'learning_rate':trial.suggest_float('lr',0.01,0.3,log=True),
        'num_leaves':trial.suggest_int('num_leaves',16,128,log=True),
        'max_depth':trial.suggest_int('max_depth',3,12),
        'feature_fraction':trial.suggest_float('feature_fraction',0.5,1.0),
        'bagging_fraction':trial.suggest_float('bagging_fraction',0.5,1.0),
        'bagging_freq':trial.suggest_int('bagging_freq',1,10),
        'lambda_l1':trial.suggest_float('lambda_l1',0.0,5.0),
        'lambda_l2':trial.suggest_float('lambda_l2',0.0,5.0),
    }
    cv = []
    for tr_i, va_i in skf.split(X_tr,y_tr):
        m = LGBMClassifier(**params, n_estimators=400, random_state=SEED)
        m.fit(
            X_tr[tr_i], y_tr[tr_i],
            eval_set=[(X_tr[va_i],y_tr[va_i])],
            callbacks=[lgb_es(stopping_rounds=30), lgb_log(period=0)]
        )
        preds = (m.predict_proba(X_tr[va_i])[:,1]>0.5).astype(int)
        cv.append( accuracy_score(y_tr[va_i], preds) )
    return 1 - np.mean(cv)

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

def tune_xgb(trial):
    params = {
        'objective':         'binary:logistic',
        'learning_rate':     trial.suggest_float('lr', 0.01, 0.3, log=True),
        'max_depth':         trial.suggest_int('max_depth', 3, 12),
        'subsample':         trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree':  trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'gamma':             trial.suggest_float('gamma', 0.0, 5.0),
        'min_child_weight':  trial.suggest_int('min_child_weight', 1, 20),
        'reg_lambda':        trial.suggest_float('reg_lambda', 0.0, 5.0),
        'scale_pos_weight':  pos_weight,
        'n_estimators':      400,
        'tree_method':       'hist',
        'verbosity':         0,
        'random_state':      SEED
    }
    cv_scores = []
    for tr_idx, va_idx in skf.split(X_tr, y_tr):
        m = XGBClassifier(**params)
        # 단순 학습만
        m.fit(X_tr[tr_idx], y_tr[tr_idx])
        preds = (m.predict_proba(X_tr[va_idx])[:, 1] > 0.5).astype(int)
        cv_scores.append( accuracy_score(y_tr[va_idx], preds) )
    return 1.0 - np.mean(cv_scores)

# %%
def tune_cat(trial):
    params = {
        'depth':trial.suggest_int('depth',4,10),
        'learning_rate':trial.suggest_float('lr',0.01,0.3,log=True),
        'l2_leaf_reg':trial.suggest_float('l2_leaf_reg',1.0,10.0,log=True),
        'bagging_temperature':trial.suggest_float('bagging_temperature',0.0,1.0),
        'border_count':trial.suggest_int('border_count',32,255),
        'iterations':400,'loss_function':'Logloss','eval_metric':'Accuracy',
        'random_seed':SEED,'verbose':False,'auto_class_weights':'Balanced'
    }
    cv=[]
    for tr_i, va_i in skf.split(X_tr,y_tr):
        m = CatBoostClassifier(**params)
        m.fit(
            X_tr[tr_i], y_tr[tr_i],
            eval_set=(X_tr[va_i], y_tr[va_i]),
            early_stopping_rounds=30, verbose=False
        )
        preds = (m.predict_proba(X_tr[va_i])[:,1]>0.5).astype(int)
        cv.append( accuracy_score(y_tr[va_i], preds) )
    return 1 - np.mean(cv)

# Optuna 실행
study_lgb = optuna.create_study(direction='minimize'); study_lgb.optimize(tune_lgb, n_trials=NTRIAL)
study_xgb = optuna.create_study(direction='minimize'); study_xgb.optimize(tune_xgb, n_trials=NTRIAL)
study_cat = optuna.create_study(direction='minimize'); study_cat.optimize(tune_cat, n_trials=NTRIAL)

print("LGB Best Acc:", 1-study_lgb.best_value, study_lgb.best_params)
print("XGB Best Acc:", 1-study_xgb.best_value, study_xgb.best_params)
print("CAT Best Acc:", 1-study_cat.best_value, study_cat.best_params)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Optuna 실행
study_xgb = optuna.create_study(direction='minimize')
study_xgb.optimize(tune_xgb, n_trials=NTRIAL)
# Out:
# [I 2025-05-28 17:05:58,325] A new study created in memory with name: no-name-dc98e9f5-328d-4110-8fc6-c20da26ead34
# [I 2025-05-28 17:06:02,571] Trial 0 finished with value: 0.10471273938384673 and parameters: {'lr': 0.030222960491204386, 'max_depth': 11, 'subsample': 0.7266186373756075, 'colsample_bytree': 0.5425325224265484, 'gamma': 1.0787473798847458, 'min_child_weight': 1, 'reg_lambda': 0.3517433027609246}. Best is trial 0 with value: 0.10471273938384673.
# [I 2025-05-28 17:06:04,101] Trial 1 finished with value: 0.11883430474604495 and parameters: {'lr': 0.05018759393359655, 'max_depth': 4, 'subsample': 0.5415293268417073, 'colsample_bytree': 0.6820287428489263, 'gamma': 3.790631501647777, 'min_child_weight': 8, 'reg_lambda': 2.480135171407362}. Best is trial 0 with value: 0.10471273938384673.
# [I 2025-05-28 17:06:06,589] Trial 2 finished with value: 0.11856786011656961 and parameters: {'lr': 0.0170029601308787, 'max_depth': 6, 'subsample': 0.8588119408522628, 'colsample_bytree': 0.9646686781332342, 'gamma': 4.504825604989305, 'min_child_weight': 5, 'reg_lambda': 0.18213551304003261}. Best is trial 0 with value: 0.10471273938384673.
# [I 2025-05-28 17:06:12,062] Trial 3 finished with value: 0.11550374687760212 and parameters: {'lr': 0.17255468989003683, 'max_depth': 6, 'subsample': 0.645111739242928, 'colsample_bytree': 0.9616702455301904, 'gamma': 0.620667959536928, 'min_child_weight': 19, 'reg_lambda': 1.1399467672581616}. Best is trial 0 with value: 0.10471273938384673.
# [I 2025-05-28 17:06:14,121] Trial 4 finished with value: 0.1171357202331389 and parameters: {'lr': 0.027660625048133554, 'max_depth': 6, 'subsample': 0.629383238413673, 'colsample_bytree': 0.6787496557703996, 'gamma': 2.9334536579102686, 'min_child_weight': 16, 'reg_lambda': 4.962821592844801}. Best is trial 0 with value: 0.10471273938384673.
# [I 2025-05-28 17:06:16,763] Trial 5 finished with value: 0.1149375520399667 and parameters: {'lr': 0.24308719104940013, 'max_depth': 5, 'subsample': 0.6620331329133324, 'colsample_bytree': 0.8262653248484634, 'gamma': 1.3479556331202502, 'min_child_weight': 2, 'reg_lambda': 0.6640221068910312}. Best is trial 0 with value: 0.10471273938384673.
# [I 2025-05-28 17:06:19,972] Trial 6 finished with value: 0.10947543713572028 and parameters: {'lr': 0.023773056480916203, 'max_depth': 11, 'subsample': 0.9683470880847906, 'colsample_bytree': 0.6210275411943421, 'gamma': 1.4095043174546862, 'min_child_weight': 8, 'reg_lambda': 1.9287737510170082}. Best is trial 0 with value: 0.10471273938384673.
# [I 2025-05-28 17:06:21,508] Trial 7 finished with value: 0.11686927560366356 and parameters: {'lr': 0.1652330941956146, 'max_depth': 7, 'subsample': 0.6281152934218706, 'colsample_bytree': 0.9999669948670249, 'gamma': 2.801166013320012, 'min_child_weight': 12, 'reg_lambda': 2.3200277123858064}. Best is trial 0 with value: 0.10471273938384673.
# [I 2025-05-28 17:06:26,621] Trial 8 finished with value: 0.11743547044129898 and parameters: {'lr': 0.01691929374711313, 'max_depth': 10, 'subsample': 0.7472932419065469, 'colsample_bytree': 0.9695211686936362, 'gamma': 4.777273537625862, 'min_child_weight': 12, 'reg_lambda': 1.5252096420653523}. Best is trial 0 with value: 0.10471273938384673.
# [I 2025-05-28 17:06:28,798] Trial 9 finished with value: 0.11570358034970862 and parameters: {'lr': 0.06226379560716355, 'max_depth': 4, 'subsample': 0.6675200947657662, 'colsample_bytree': 0.9030227034204674, 'gamma': 1.529948757788523, 'min_child_weight': 2, 'reg_lambda': 3.3291194277717837}. Best is trial 0 with value: 0.10471273938384673.
# [I 2025-05-28 17:06:32,986] Trial 10 finished with value: 0.10711074104912566 and parameters: {'lr': 0.05700059468532355, 'max_depth': 9, 'subsample': 0.812629253046607, 'colsample_bytree': 0.5074274441034488, 'gamma': 0.30405897009559535, 'min_child_weight': 5, 'reg_lambda': 3.7978124305205685}. Best is trial 0 with value: 0.10471273938384673.
# [I 2025-05-28 17:06:40,850] Trial 11 finished with value: 0.10398001665278933 and parameters: {'lr': 0.05716408243561153, 'max_depth': 9, 'subsample': 0.824609568955871, 'colsample_bytree': 0.5137062930540741, 'gamma': 0.030327733807739343, 'min_child_weight': 1, 'reg_lambda': 3.7505477127413367}. Best is trial 11 with value: 0.10398001665278933.
# [I 2025-05-28 17:06:48,661] Trial 12 finished with value: 0.10727726894254785 and parameters: {'lr': 0.010129563454907432, 'max_depth': 12, 'subsample': 0.8980204633035722, 'colsample_bytree': 0.5113466738998489, 'gamma': 0.2815995872430429, 'min_child_weight': 1, 'reg_lambda': 3.5185177564934484}. Best is trial 11 with value: 0.10398001665278933.
# [I 2025-05-28 17:06:52,689] Trial 13 finished with value: 0.1142048293089093 and parameters: {'lr': 0.08570429922339873, 'max_depth': 9, 'subsample': 0.7698612666546372, 'colsample_bytree': 0.5856190868756396, 'gamma': 1.9579368807957733, 'min_child_weight': 5, 'reg_lambda': 4.632188936443555}. Best is trial 11 with value: 0.10398001665278933.
# [I 2025-05-28 17:07:00,218] Trial 14 finished with value: 0.10414654454621153 and parameters: {'lr': 0.03552335287007544, 'max_depth': 9, 'subsample': 0.7354171114894833, 'colsample_bytree': 0.5735765724477154, 'gamma': 0.13632094442901715, 'min_child_weight': 1, 'reg_lambda': 3.101133999393279}. Best is trial 11 with value: 0.10398001665278933.
# [I 2025-05-28 17:07:06,015] Trial 15 finished with value: 0.10877601998334718 and parameters: {'lr': 0.10794574424763671, 'max_depth': 8, 'subsample': 0.9264901083163969, 'colsample_bytree': 0.7790475197802033, 'gamma': 0.06210138617429549, 'min_child_weight': 8, 'reg_lambda': 4.092797708746508}. Best is trial 11 with value: 0.10398001665278933.
# [I 2025-05-28 17:07:10,104] Trial 16 finished with value: 0.1086094920899251 and parameters: {'lr': 0.041508972914841596, 'max_depth': 8, 'subsample': 0.8389302467765041, 'colsample_bytree': 0.625751659333285, 'gamma': 0.7982045299534304, 'min_child_weight': 4, 'reg_lambda': 3.026452351541172}. Best is trial 11 with value: 0.10398001665278933.
# [I 2025-05-28 17:07:12,564] Trial 17 finished with value: 0.11117402164862611 and parameters: {'lr': 0.0900143702895605, 'max_depth': 9, 'subsample': 0.5246311798135015, 'colsample_bytree': 0.7027753177374002, 'gamma': 1.8445078208239047, 'min_child_weight': 3, 'reg_lambda': 2.957086141820521}. Best is trial 11 with value: 0.10398001665278933.
# [I 2025-05-28 17:07:17,373] Trial 18 finished with value: 0.11613655287260616 and parameters: {'lr': 0.07071730386292924, 'max_depth': 10, 'subsample': 0.7903721794081366, 'colsample_bytree': 0.576742980585281, 'gamma': 2.3220702663376382, 'min_child_weight': 15, 'reg_lambda': 4.2389809772692075}. Best is trial 11 with value: 0.10398001665278933.
# [I 2025-05-28 17:07:21,571] Trial 19 finished with value: 0.11770191507077432 and parameters: {'lr': 0.03908900702570362, 'max_depth': 7, 'subsample': 0.7213909843513393, 'colsample_bytree': 0.6231981500907039, 'gamma': 3.4031318282568463, 'min_child_weight': 6, 'reg_lambda': 3.0543624851077142}. Best is trial 11 with value: 0.10398001665278933.
# [I 2025-05-28 17:07:24,166] Trial 20 finished with value: 0.1091756869275603 and parameters: {'lr': 0.13587822023288, 'max_depth': 12, 'subsample': 0.8818172664312134, 'colsample_bytree': 0.7586640972458853, 'gamma': 0.7041927857035181, 'min_child_weight': 10, 'reg_lambda': 4.2090495295199695}. Best is trial 11 with value: 0.10398001665278933.
# [I 2025-05-28 17:07:28,741] Trial 21 finished with value: 0.10294754371357207 and parameters: {'lr': 0.028112441216490234, 'max_depth': 11, 'subsample': 0.7036218944491096, 'colsample_bytree': 0.5456207291788101, 'gamma': 0.9568042968171635, 'min_child_weight': 1, 'reg_lambda': 0.09605447574391424}. Best is trial 21 with value: 0.10294754371357207.
# [I 2025-05-28 17:07:37,699] Trial 22 finished with value: 0.10344712739383843 and parameters: {'lr': 0.02066579268187789, 'max_depth': 10, 'subsample': 0.7079442536550824, 'colsample_bytree': 0.5572814836909651, 'gamma': 0.009070820392222116, 'min_child_weight': 1, 'reg_lambda': 1.9734055346627846}. Best is trial 21 with value: 0.10294754371357207.
# [I 2025-05-28 17:07:42,784] Trial 23 finished with value: 0.10741049125728563 and parameters: {'lr': 0.020051922970337803, 'max_depth': 11, 'subsample': 0.5931833905996123, 'colsample_bytree': 0.5383168415389722, 'gamma': 0.8705987429722312, 'min_child_weight': 3, 'reg_lambda': 1.3413058716720014}. Best is trial 21 with value: 0.10294754371357207.
# [I 2025-05-28 17:07:50,748] Trial 24 finished with value: 0.10834304746044965 and parameters: {'lr': 0.011753203471047467, 'max_depth': 10, 'subsample': 0.6949453862586544, 'colsample_bytree': 0.5011248648915311, 'gamma': 0.48256603723737157, 'min_child_weight': 3, 'reg_lambda': 0.7984605158033999}. Best is trial 21 with value: 0.10294754371357207.
# [I 2025-05-28 17:07:58,998] Trial 25 finished with value: 0.10854288093255615 and parameters: {'lr': 0.01649108255159889, 'max_depth': 11, 'subsample': 0.8142594675793331, 'colsample_bytree': 0.5522552101026565, 'gamma': 0.04687748955977672, 'min_child_weight': 7, 'reg_lambda': 2.0436203074690935}. Best is trial 21 with value: 0.10294754371357207.
# [I 2025-05-28 17:08:05,154] Trial 26 finished with value: 0.10531223980016657 and parameters: {'lr': 0.047153896785271376, 'max_depth': 10, 'subsample': 0.6981818264451379, 'colsample_bytree': 0.6549453518657601, 'gamma': 1.044264683720483, 'min_child_weight': 1, 'reg_lambda': 1.5504284664803882}. Best is trial 21 with value: 0.10294754371357207.
# [I 2025-05-28 17:08:10,821] Trial 27 finished with value: 0.10651124063280604 and parameters: {'lr': 0.024220481022173158, 'max_depth': 12, 'subsample': 0.580305035015098, 'colsample_bytree': 0.7203355501155426, 'gamma': 0.5590272164803958, 'min_child_weight': 4, 'reg_lambda': 1.9338911993637913}. Best is trial 21 with value: 0.10294754371357207.
# [I 2025-05-28 17:08:17,018] Trial 28 finished with value: 0.1142381348875936 and parameters: {'lr': 0.014163642798506288, 'max_depth': 8, 'subsample': 0.7751358152843018, 'colsample_bytree': 0.6089557917925549, 'gamma': 0.0218863935176993, 'min_child_weight': 20, 'reg_lambda': 2.6983957758132493}. Best is trial 21 with value: 0.10294754371357207.
# [I 2025-05-28 17:08:21,189] Trial 29 finished with value: 0.1044462947543714 and parameters: {'lr': 0.032948894163413046, 'max_depth': 11, 'subsample': 0.6994574700086007, 'colsample_bytree': 0.5473725806156947, 'gamma': 1.0260966051278433, 'min_child_weight': 1, 'reg_lambda': 0.4838386853395156}. Best is trial 21 with value: 0.10294754371357207.
# [I 2025-05-28 17:08:23,817] Trial 30 finished with value: 0.10897585345545369 and parameters: {'lr': 0.029235889682021367, 'max_depth': 10, 'subsample': 0.9942424397733446, 'colsample_bytree': 0.5277517546668419, 'gamma': 1.757754589145574, 'min_child_weight': 3, 'reg_lambda': 0.06256861237315503}. Best is trial 21 with value: 0.10294754371357207.
# [I 2025-05-28 17:08:31,557] Trial 31 finished with value: 0.10551207327227308 and parameters: {'lr': 0.03436272053247786, 'max_depth': 9, 'subsample': 0.7321209678181064, 'colsample_bytree': 0.5670598793171844, 'gamma': 0.3346759956684263, 'min_child_weight': 1, 'reg_lambda': 3.597336334389124}. Best is trial 21 with value: 0.10294754371357207.
# [I 2025-05-28 17:08:35,471] Trial 32 finished with value: 0.10874271440466265 and parameters: {'lr': 0.023583847314344302, 'max_depth': 9, 'subsample': 0.7473399527270015, 'colsample_bytree': 0.5888435068652558, 'gamma': 1.2153297457894152, 'min_child_weight': 2, 'reg_lambda': 3.8405796742108365}. Best is trial 21 with value: 0.10294754371357207.
# [I 2025-05-28 17:08:44,702] Trial 33 finished with value: 0.10311407160699415 and parameters: {'lr': 0.04312270377359826, 'max_depth': 10, 'subsample': 0.8151612268390508, 'colsample_bytree': 0.661072288525562, 'gamma': 0.010028035713113614, 'min_child_weight': 1, 'reg_lambda': 2.690362619419591}. Best is trial 21 with value: 0.10294754371357207.
# [I 2025-05-28 17:08:49,213] Trial 34 finished with value: 0.1059117402164862 and parameters: {'lr': 0.05028269108743155, 'max_depth': 10, 'subsample': 0.8306397580080181, 'colsample_bytree': 0.646236884559787, 'gamma': 0.5067425686845679, 'min_child_weight': 4, 'reg_lambda': 2.644753981336613}. Best is trial 21 with value: 0.10294754371357207.
# [I 2025-05-28 17:08:50,909] Trial 35 finished with value: 0.11776852622814327 and parameters: {'lr': 0.04179457148584284, 'max_depth': 11, 'subsample': 0.8571806341729914, 'colsample_bytree': 0.6803373144813244, 'gamma': 4.00241422176496, 'min_child_weight': 6, 'reg_lambda': 2.2755667029010147}. Best is trial 21 with value: 0.10294754371357207.
# [I 2025-05-28 17:08:59,025] Trial 36 finished with value: 0.10411323896752711 and parameters: {'lr': 0.02075259762435476, 'max_depth': 12, 'subsample': 0.7946347031158404, 'colsample_bytree': 0.5316524557545466, 'gamma': 0.8112743936357362, 'min_child_weight': 2, 'reg_lambda': 0.990554777225978}. Best is trial 21 with value: 0.10294754371357207.
# [I 2025-05-28 17:09:02,516] Trial 37 finished with value: 0.10950874271440458 and parameters: {'lr': 0.07114416818660523, 'max_depth': 8, 'subsample': 0.9222188201736412, 'colsample_bytree': 0.6017671333229985, 'gamma': 0.431785857754595, 'min_child_weight': 10, 'reg_lambda': 0.24175720754049554}. Best is trial 21 with value: 0.10294754371357207.
# [I 2025-05-28 17:09:05,032] Trial 38 finished with value: 0.11570358034970862 and parameters: {'lr': 0.026809223170032835, 'max_depth': 11, 'subsample': 0.6717194924748671, 'colsample_bytree': 0.6412031348846514, 'gamma': 2.3714139606040696, 'min_child_weight': 17, 'reg_lambda': 4.470218141619659}. Best is trial 21 with value: 0.10294754371357207.
# [I 2025-05-28 17:09:06,925] Trial 39 finished with value: 0.1180016652789343 and parameters: {'lr': 0.01424563367802477, 'max_depth': 3, 'subsample': 0.7667784768398364, 'colsample_bytree': 0.8644312399071855, 'gamma': 1.1913010668158337, 'min_child_weight': 2, 'reg_lambda': 2.7009601183995415}. Best is trial 21 with value: 0.10294754371357207.
# [I 2025-05-28 17:09:12,502] Trial 40 finished with value: 0.11020815986677768 and parameters: {'lr': 0.048695289850376765, 'max_depth': 10, 'subsample': 0.6359599766700664, 'colsample_bytree': 0.8002879717158806, 'gamma': 1.600621759460945, 'min_child_weight': 5, 'reg_lambda': 1.5621860037102182}. Best is trial 21 with value: 0.10294754371357207.
# [I 2025-05-28 17:09:18,189] Trial 41 finished with value: 0.10431307243963361 and parameters: {'lr': 0.01966865499841191, 'max_depth': 12, 'subsample': 0.7968373875577675, 'colsample_bytree': 0.5355091039883266, 'gamma': 0.8027321223775055, 'min_child_weight': 2, 'reg_lambda': 0.9117817841806034}. Best is trial 21 with value: 0.10294754371357207.
# [I 2025-05-28 17:09:27,286] Trial 42 finished with value: 0.10358034970857621 and parameters: {'lr': 0.020635544998676137, 'max_depth': 11, 'subsample': 0.8642904169149528, 'colsample_bytree': 0.5570442767798557, 'gamma': 0.21328318811505478, 'min_child_weight': 2, 'reg_lambda': 1.0825295165367006}. Best is trial 21 with value: 0.10294754371357207.
# [I 2025-05-28 17:09:34,257] Trial 43 finished with value: 0.10071606994171522 and parameters: {'lr': 0.029571571506010003, 'max_depth': 11, 'subsample': 0.8662570080808631, 'colsample_bytree': 0.5567859371176622, 'gamma': 0.16941740915054604, 'min_child_weight': 1, 'reg_lambda': 0.5117728127951874}. Best is trial 43 with value: 0.10071606994171522.
# [I 2025-05-28 17:09:42,289] Trial 44 finished with value: 0.10571190674437969 and parameters: {'lr': 0.02926044815797661, 'max_depth': 11, 'subsample': 0.8634307839948574, 'colsample_bytree': 0.5618446877657636, 'gamma': 0.2657999823330338, 'min_child_weight': 4, 'reg_lambda': 0.31125362295392434}. Best is trial 43 with value: 0.10071606994171522.
# [I 2025-05-28 17:09:47,370] Trial 45 finished with value: 0.1046461282264779 and parameters: {'lr': 0.02421566703780017, 'max_depth': 11, 'subsample': 0.9262281510067868, 'colsample_bytree': 0.6584876038244313, 'gamma': 0.6105372554597605, 'min_child_weight': 3, 'reg_lambda': 0.5999078457146898}. Best is trial 43 with value: 0.10071606994171522.
# [I 2025-05-28 17:09:52,565] Trial 46 finished with value: 0.10531223980016657 and parameters: {'lr': 0.28873948731538, 'max_depth': 12, 'subsample': 0.8792460675915165, 'colsample_bytree': 0.7112481469560267, 'gamma': 0.2813939525715743, 'min_child_weight': 1, 'reg_lambda': 1.2951004376480633}. Best is trial 43 with value: 0.10071606994171522.
# [I 2025-05-28 17:09:58,816] Trial 47 finished with value: 0.1035470441298918 and parameters: {'lr': 0.017432392591966012, 'max_depth': 10, 'subsample': 0.8435197719035252, 'colsample_bytree': 0.5920671990217871, 'gamma': 0.18765210452771675, 'min_child_weight': 2, 'reg_lambda': 0.439756803672301}. Best is trial 43 with value: 0.10071606994171522.
# [I 2025-05-28 17:10:01,940] Trial 48 finished with value: 0.11540383014154876 and parameters: {'lr': 0.015193311924663526, 'max_depth': 10, 'subsample': 0.906912828795711, 'colsample_bytree': 0.6015821752626579, 'gamma': 2.778810868079801, 'min_child_weight': 12, 'reg_lambda': 0.07101380320644524}. Best is trial 43 with value: 0.10071606994171522.
# [I 2025-05-28 17:10:07,596] Trial 49 finished with value: 0.11533721898417981 and parameters: {'lr': 0.013129538147165864, 'max_depth': 6, 'subsample': 0.9483903834590272, 'colsample_bytree': 0.629193492234092, 'gamma': 1.3614008021817587, 'min_child_weight': 6, 'reg_lambda': 0.5435392458345685}. Best is trial 43 with value: 0.10071606994171522.
# [I 2025-05-28 17:10:12,012] Trial 50 finished with value: 0.11203996669442129 and parameters: {'lr': 0.016986484517923495, 'max_depth': 10, 'subsample': 0.8470992826977785, 'colsample_bytree': 0.5895149001048172, 'gamma': 0.49136167665197544, 'min_child_weight': 14, 'reg_lambda': 0.7243189812225754}. Best is trial 43 with value: 0.10071606994171522.
# [I 2025-05-28 17:10:21,256] Trial 51 finished with value: 0.10338051623646971 and parameters: {'lr': 0.01952842995748304, 'max_depth': 11, 'subsample': 0.8699483935717587, 'colsample_bytree': 0.5578247185098918, 'gamma': 0.22412210853551112, 'min_child_weight': 2, 'reg_lambda': 0.42989284190570115}. Best is trial 43 with value: 0.10071606994171522.
# [I 2025-05-28 17:10:28,612] Trial 52 finished with value: 0.10008326394671108 and parameters: {'lr': 0.02729981233608291, 'max_depth': 11, 'subsample': 0.8878512902619031, 'colsample_bytree': 0.5205028915607856, 'gamma': 0.01196000128983285, 'min_child_weight': 1, 'reg_lambda': 0.42477001412654536}. Best is trial 52 with value: 0.10008326394671108.
# [I 2025-05-28 17:10:38,191] Trial 53 finished with value: 0.09968359700249785 and parameters: {'lr': 0.032532111147427586, 'max_depth': 11, 'subsample': 0.8970969017618952, 'colsample_bytree': 0.5179945005269921, 'gamma': 0.016508932515318583, 'min_child_weight': 1, 'reg_lambda': 0.2715947195109578}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:10:42,652] Trial 54 finished with value: 0.10294754371357195 and parameters: {'lr': 0.03792359122768076, 'max_depth': 12, 'subsample': 0.9510817543627372, 'colsample_bytree': 0.5217725404349878, 'gamma': 0.4076058919993596, 'min_child_weight': 3, 'reg_lambda': 0.27020538777815284}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:10:49,011] Trial 55 finished with value: 0.10351373855120727 and parameters: {'lr': 0.03870995308629814, 'max_depth': 12, 'subsample': 0.9533832852210047, 'colsample_bytree': 0.5104278928682551, 'gamma': 0.6622185684599108, 'min_child_weight': 3, 'reg_lambda': 0.022086335185226014}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:10:52,614] Trial 56 finished with value: 0.10141548709408821 and parameters: {'lr': 0.03440227308422083, 'max_depth': 12, 'subsample': 0.9087388430298946, 'colsample_bytree': 0.5213722964747542, 'gamma': 0.9693510527513564, 'min_child_weight': 1, 'reg_lambda': 0.24667299477999727}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:10:55,976] Trial 57 finished with value: 0.10431307243963361 and parameters: {'lr': 0.03160191148346861, 'max_depth': 12, 'subsample': 0.9864094029683227, 'colsample_bytree': 0.5123188204598805, 'gamma': 0.9561175953545558, 'min_child_weight': 3, 'reg_lambda': 0.17268103091179055}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:11:00,782] Trial 58 finished with value: 0.11050791007493754 and parameters: {'lr': 0.025858664294057136, 'max_depth': 12, 'subsample': 0.9058871220953296, 'colsample_bytree': 0.5288993237129104, 'gamma': 2.0803071499258516, 'min_child_weight': 5, 'reg_lambda': 0.22936094604110158}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:11:03,659] Trial 59 finished with value: 0.11347210657785178 and parameters: {'lr': 0.03710584156767455, 'max_depth': 5, 'subsample': 0.9509763938478946, 'colsample_bytree': 0.5031061358182198, 'gamma': 0.40113328959226013, 'min_child_weight': 4, 'reg_lambda': 0.8176870792266844}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:11:05,865] Trial 60 finished with value: 0.10454621149042465 and parameters: {'lr': 0.055376711907161286, 'max_depth': 11, 'subsample': 0.9658301591438277, 'colsample_bytree': 0.5248042490134603, 'gamma': 1.2628319014267102, 'min_child_weight': 1, 'reg_lambda': 0.7079794387075102}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:11:09,506] Trial 61 finished with value: 0.10168193172356366 and parameters: {'lr': 0.04507809131257303, 'max_depth': 12, 'subsample': 0.8938914383474007, 'colsample_bytree': 0.54085194133005, 'gamma': 0.6639826474354658, 'min_child_weight': 1, 'reg_lambda': 0.3210814373477804}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:11:16,557] Trial 62 finished with value: 0.10021648626144875 and parameters: {'lr': 0.032623311958480554, 'max_depth': 12, 'subsample': 0.8876779593310673, 'colsample_bytree': 0.5460390212041771, 'gamma': 0.6531451992038637, 'min_child_weight': 1, 'reg_lambda': 0.3820281137081426}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:11:21,193] Trial 63 finished with value: 0.10278101582014987 and parameters: {'lr': 0.032767401687616736, 'max_depth': 12, 'subsample': 0.891360170940923, 'colsample_bytree': 0.5742139181367344, 'gamma': 0.6439859556838368, 'min_child_weight': 2, 'reg_lambda': 0.36498552681745167}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:11:25,897] Trial 64 finished with value: 0.10214820982514561 and parameters: {'lr': 0.03207010248556409, 'max_depth': 12, 'subsample': 0.8924843157639755, 'colsample_bytree': 0.5474968764082159, 'gamma': 0.6226339372013266, 'min_child_weight': 2, 'reg_lambda': 0.5706229142378806}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:11:30,674] Trial 65 finished with value: 0.10677768526228137 and parameters: {'lr': 0.04484421054533403, 'max_depth': 12, 'subsample': 0.920490144158581, 'colsample_bytree': 0.5457769460944728, 'gamma': 1.5301585698640638, 'min_child_weight': 1, 'reg_lambda': 0.6112797484982775}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:11:32,167] Trial 66 finished with value: 0.11513738551207331 and parameters: {'lr': 0.06304742699551384, 'max_depth': 12, 'subsample': 0.8939799687425073, 'colsample_bytree': 0.5006018739911111, 'gamma': 3.4278731602059227, 'min_child_weight': 1, 'reg_lambda': 1.250224530646412}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:11:36,181] Trial 67 finished with value: 0.10414654454621153 and parameters: {'lr': 0.03228972574735048, 'max_depth': 11, 'subsample': 0.9073053042707614, 'colsample_bytree': 0.5749758236144789, 'gamma': 0.7326147883251997, 'min_child_weight': 3, 'reg_lambda': 0.9324803297942781}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:11:40,046] Trial 68 finished with value: 0.10441298917568687 and parameters: {'lr': 0.02942682496712097, 'max_depth': 12, 'subsample': 0.9379663809567041, 'colsample_bytree': 0.5403607772812924, 'gamma': 1.066587198566289, 'min_child_weight': 2, 'reg_lambda': 0.5111178397192687}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:11:49,954] Trial 69 finished with value: 0.10148209825145715 and parameters: {'lr': 0.02337787254778036, 'max_depth': 11, 'subsample': 0.885151546609361, 'colsample_bytree': 0.6149176506604944, 'gamma': 0.1332203509084503, 'min_child_weight': 1, 'reg_lambda': 0.816718891085681}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:11:57,539] Trial 70 finished with value: 0.10817651956702756 and parameters: {'lr': 0.023494011780052927, 'max_depth': 11, 'subsample': 0.8772019087604176, 'colsample_bytree': 0.6137717608829254, 'gamma': 0.13430854927334313, 'min_child_weight': 9, 'reg_lambda': 1.12907029229919}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:12:02,267] Trial 71 finished with value: 0.10264779350541231 and parameters: {'lr': 0.03387138535067456, 'max_depth': 11, 'subsample': 0.883502501664509, 'colsample_bytree': 0.5250989076823634, 'gamma': 0.5532013330910205, 'min_child_weight': 1, 'reg_lambda': 0.7693335932315115}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:12:06,904] Trial 72 finished with value: 0.10148209825145715 and parameters: {'lr': 0.027265546612368158, 'max_depth': 12, 'subsample': 0.8532794846255707, 'colsample_bytree': 0.5663870517582813, 'gamma': 0.8947211990325296, 'min_child_weight': 1, 'reg_lambda': 0.2704494940467345}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:12:13,940] Trial 73 finished with value: 0.10281432139883417 and parameters: {'lr': 0.027359394409383574, 'max_depth': 11, 'subsample': 0.850062911199596, 'colsample_bytree': 0.5794284386371413, 'gamma': 0.865168177119088, 'min_child_weight': 1, 'reg_lambda': 0.35178016670139967}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:12:24,289] Trial 74 finished with value: 0.0999167360532891 and parameters: {'lr': 0.02285792719361838, 'max_depth': 12, 'subsample': 0.8285114728865283, 'colsample_bytree': 0.5659633384724471, 'gamma': 0.30878560420989, 'min_child_weight': 1, 'reg_lambda': 0.12007202415453438}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:12:33,608] Trial 75 finished with value: 0.1029808492922566 and parameters: {'lr': 0.022384695983830236, 'max_depth': 11, 'subsample': 0.8350561037188569, 'colsample_bytree': 0.5627035129496097, 'gamma': 0.3243826401472696, 'min_child_weight': 2, 'reg_lambda': 0.03683945158291624}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:12:42,252] Trial 76 finished with value: 0.1042797668609492 and parameters: {'lr': 0.02574676805162837, 'max_depth': 12, 'subsample': 0.9157583129533603, 'colsample_bytree': 0.5200505416237126, 'gamma': 0.1143786821236561, 'min_child_weight': 4, 'reg_lambda': 0.16997695604316243}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:12:48,430] Trial 77 finished with value: 0.10361365528726052 and parameters: {'lr': 0.02248136007428389, 'max_depth': 11, 'subsample': 0.822757301475149, 'colsample_bytree': 0.6008828621744213, 'gamma': 0.14944209876275077, 'min_child_weight': 3, 'reg_lambda': 0.4364108830177201}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:12:53,328] Trial 78 finished with value: 0.11856786011656939 and parameters: {'lr': 0.018767025995799592, 'max_depth': 12, 'subsample': 0.9375369220926301, 'colsample_bytree': 0.5674192225180311, 'gamma': 4.9485885277850565, 'min_child_weight': 2, 'reg_lambda': 1.7496769994037797}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:13:00,048] Trial 79 finished with value: 0.10164862614487924 and parameters: {'lr': 0.03563992439828561, 'max_depth': 11, 'subsample': 0.8044841426584772, 'colsample_bytree': 0.7384890903687905, 'gamma': 0.37517389489227504, 'min_child_weight': 1, 'reg_lambda': 0.8554526759529615}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:13:07,607] Trial 80 finished with value: 0.11174021648626142 and parameters: {'lr': 0.025900926928638046, 'max_depth': 12, 'subsample': 0.8589915935601818, 'colsample_bytree': 0.8904169106738287, 'gamma': 0.054951328697175894, 'min_child_weight': 18, 'reg_lambda': 0.16194842958730893}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:13:14,382] Trial 81 finished with value: 0.10131557035803485 and parameters: {'lr': 0.03584418147584528, 'max_depth': 11, 'subsample': 0.806706174560547, 'colsample_bytree': 0.7582074121068579, 'gamma': 0.3789143030825164, 'min_child_weight': 1, 'reg_lambda': 0.8367374759649687}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:13:22,172] Trial 82 finished with value: 0.1028143213988344 and parameters: {'lr': 0.04086528909915609, 'max_depth': 11, 'subsample': 0.8726438532958868, 'colsample_bytree': 0.7757877753431, 'gamma': 0.5027363574896522, 'min_child_weight': 1, 'reg_lambda': 1.0217987784624727}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:13:26,944] Trial 83 finished with value: 0.11047460449625324 and parameters: {'lr': 0.029543067831756097, 'max_depth': 11, 'subsample': 0.7831190469883751, 'colsample_bytree': 0.8224635439377298, 'gamma': 0.2885902128318256, 'min_child_weight': 13, 'reg_lambda': 0.6897596163804607}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:13:37,211] Trial 84 finished with value: 0.1028143213988344 and parameters: {'lr': 0.022129514018480886, 'max_depth': 12, 'subsample': 0.8309142753031226, 'colsample_bytree': 0.7246200006286686, 'gamma': 0.0013414467877412295, 'min_child_weight': 2, 'reg_lambda': 0.6178102560092227}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:13:41,798] Trial 85 finished with value: 0.1028476269775187 and parameters: {'lr': 0.02764045586431606, 'max_depth': 10, 'subsample': 0.8166073904514246, 'colsample_bytree': 0.7855839068466314, 'gamma': 0.9497003928251232, 'min_child_weight': 1, 'reg_lambda': 0.0063759632523783805}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:13:47,529] Trial 86 finished with value: 0.1052123230641131 and parameters: {'lr': 0.03589378468283131, 'max_depth': 12, 'subsample': 0.8511753170702625, 'colsample_bytree': 0.7658523308569944, 'gamma': 1.144509649093302, 'min_child_weight': 3, 'reg_lambda': 0.44639273004453}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:13:51,779] Trial 87 finished with value: 0.1084429641965029 and parameters: {'lr': 0.030281294121284982, 'max_depth': 7, 'subsample': 0.8371108006791056, 'colsample_bytree': 0.6988935772896572, 'gamma': 0.4129551767838332, 'min_child_weight': 2, 'reg_lambda': 0.2709797714659965}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:13:57,419] Trial 88 finished with value: 0.10101582014987509 and parameters: {'lr': 0.050374987813263286, 'max_depth': 10, 'subsample': 0.758642596986487, 'colsample_bytree': 0.5148732083434383, 'gamma': 0.21551236029601478, 'min_child_weight': 1, 'reg_lambda': 0.1759449843960587}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:14:04,858] Trial 89 finished with value: 0.1055453788509576 and parameters: {'lr': 0.06137332655471317, 'max_depth': 10, 'subsample': 0.7599306122539463, 'colsample_bytree': 0.5147019722466368, 'gamma': 0.22398001945851023, 'min_child_weight': 3, 'reg_lambda': 1.4339216009400402}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:14:09,227] Trial 90 finished with value: 0.10344712739383843 and parameters: {'lr': 0.050931833674448035, 'max_depth': 11, 'subsample': 0.7992907972238034, 'colsample_bytree': 0.5371345744384093, 'gamma': 0.519031873145128, 'min_child_weight': 2, 'reg_lambda': 0.11428045451485899}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:14:15,748] Trial 91 finished with value: 0.10251457119067453 and parameters: {'lr': 0.04043352684573435, 'max_depth': 11, 'subsample': 0.8653743089353658, 'colsample_bytree': 0.7455847504180138, 'gamma': 0.7432552920302387, 'min_child_weight': 1, 'reg_lambda': 0.4132662370883381}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:14:23,728] Trial 92 finished with value: 0.10024979184013316 and parameters: {'lr': 0.025694370631058186, 'max_depth': 12, 'subsample': 0.7802805267827064, 'colsample_bytree': 0.5526744462427409, 'gamma': 0.17048122690101697, 'min_child_weight': 1, 'reg_lambda': 0.5298871745007798}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:14:33,426] Trial 93 finished with value: 0.10068276436303081 and parameters: {'lr': 0.024887005788232705, 'max_depth': 11, 'subsample': 0.7813925595931602, 'colsample_bytree': 0.5140606768958712, 'gamma': 0.1278805168985517, 'min_child_weight': 1, 'reg_lambda': 0.5646852321066769}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:14:38,661] Trial 94 finished with value: 0.10694421315570357 and parameters: {'lr': 0.02460196926413992, 'max_depth': 10, 'subsample': 0.7181971145693345, 'colsample_bytree': 0.5128978208385194, 'gamma': 0.33646217099066866, 'min_child_weight': 2, 'reg_lambda': 4.986072804116288}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:14:45,698] Trial 95 finished with value: 0.10434637801831814 and parameters: {'lr': 0.18033450668149376, 'max_depth': 12, 'subsample': 0.7829279668344005, 'colsample_bytree': 0.5522923974344803, 'gamma': 0.17178658145158943, 'min_child_weight': 1, 'reg_lambda': 0.5159604053318867}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:14:51,882] Trial 96 finished with value: 0.10214820982514572 and parameters: {'lr': 0.030413743431438964, 'max_depth': 11, 'subsample': 0.7588128665566306, 'colsample_bytree': 0.5000085135599257, 'gamma': 0.011223519736033, 'min_child_weight': 2, 'reg_lambda': 0.6535849964399453}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:14:53,608] Trial 97 finished with value: 0.11750208159866771 and parameters: {'lr': 0.03536104122637715, 'max_depth': 9, 'subsample': 0.7774629806865241, 'colsample_bytree': 0.5308701907581239, 'gamma': 4.2997939055656955, 'min_child_weight': 4, 'reg_lambda': 0.16365640785958438}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:15:04,438] Trial 98 finished with value: 0.10054954204829303 and parameters: {'lr': 0.038280005890913286, 'max_depth': 12, 'subsample': 0.8035939886981874, 'colsample_bytree': 0.9553067676492248, 'gamma': 0.2689248869825155, 'min_child_weight': 1, 'reg_lambda': 0.33716463521615314}. Best is trial 53 with value: 0.09968359700249785.
# [I 2025-05-28 17:15:11,801] Trial 99 finished with value: 0.10897585345545369 and parameters: {'lr': 0.04406584804937739, 'max_depth': 10, 'subsample': 0.810490541943249, 'colsample_bytree': 0.9696389379107603, 'gamma': 0.2831156239371924, 'min_child_weight': 11, 'reg_lambda': 0.3626698454021754}. Best is trial 53 with value: 0.09968359700249785.

# %%
study_cat = optuna.create_study(direction='minimize'); study_cat.optimize(tune_cat, n_trials=NTRIAL)
# Out:
# [I 2025-05-28 17:15:26,156] A new study created in memory with name: no-name-70a925eb-e3b8-47c2-a757-2fe12d6a1242
# [I 2025-05-28 17:15:30,420] Trial 0 finished with value: 0.11413821815154035 and parameters: {'depth': 5, 'lr': 0.2502154092218885, 'l2_leaf_reg': 6.350636474947447, 'bagging_temperature': 0.6236894272229467, 'border_count': 179}. Best is trial 0 with value: 0.11413821815154035.
# [I 2025-05-28 17:15:48,303] Trial 1 finished with value: 0.11130724396336389 and parameters: {'depth': 10, 'lr': 0.020215029778073004, 'l2_leaf_reg': 8.326626190301194, 'bagging_temperature': 0.502655779427113, 'border_count': 100}. Best is trial 1 with value: 0.11130724396336389.
# [I 2025-05-28 17:15:50,607] Trial 2 finished with value: 0.12819317235636984 and parameters: {'depth': 4, 'lr': 0.015987275458910405, 'l2_leaf_reg': 1.0714348009144852, 'bagging_temperature': 0.05450997182017803, 'border_count': 227}. Best is trial 1 with value: 0.11130724396336389.
# [I 2025-05-28 17:15:55,007] Trial 3 finished with value: 0.11580349708576188 and parameters: {'depth': 6, 'lr': 0.05596826814340443, 'l2_leaf_reg': 4.503752626314042, 'bagging_temperature': 0.39250188638526795, 'border_count': 52}. Best is trial 1 with value: 0.11130724396336389.
# [I 2025-05-28 17:16:01,965] Trial 4 finished with value: 0.11054121565362196 and parameters: {'depth': 9, 'lr': 0.12730207772299468, 'l2_leaf_reg': 1.0574083226560647, 'bagging_temperature': 0.7414218635929742, 'border_count': 228}. Best is trial 4 with value: 0.11054121565362196.
# [I 2025-05-28 17:16:07,727] Trial 5 finished with value: 0.11127393838467936 and parameters: {'depth': 8, 'lr': 0.1330094710339912, 'l2_leaf_reg': 1.0924089167989726, 'bagging_temperature': 0.43695453687801544, 'border_count': 64}. Best is trial 4 with value: 0.11054121565362196.
# [I 2025-05-28 17:16:15,515] Trial 6 finished with value: 0.1102414654454622 and parameters: {'depth': 9, 'lr': 0.11434724785714212, 'l2_leaf_reg': 2.640434300183341, 'bagging_temperature': 0.1194069820804804, 'border_count': 216}. Best is trial 6 with value: 0.1102414654454622.
# [I 2025-05-28 17:16:20,136] Trial 7 finished with value: 0.12106577851790179 and parameters: {'depth': 5, 'lr': 0.03228656573884408, 'l2_leaf_reg': 7.866932041171927, 'bagging_temperature': 0.5195109708141988, 'border_count': 222}. Best is trial 6 with value: 0.1102414654454622.
# [I 2025-05-28 17:16:32,065] Trial 8 finished with value: 0.10947543713572028 and parameters: {'depth': 10, 'lr': 0.137367026091953, 'l2_leaf_reg': 9.053753255444194, 'bagging_temperature': 0.592668809956653, 'border_count': 159}. Best is trial 8 with value: 0.10947543713572028.
# [I 2025-05-28 17:16:39,023] Trial 9 finished with value: 0.11553705245628643 and parameters: {'depth': 7, 'lr': 0.023095926187571066, 'l2_leaf_reg': 5.082408085405782, 'bagging_temperature': 0.6215134090077612, 'border_count': 103}. Best is trial 8 with value: 0.10947543713572028.
# [I 2025-05-28 17:16:53,660] Trial 10 finished with value: 0.10820982514571187 and parameters: {'depth': 10, 'lr': 0.05902923570688228, 'l2_leaf_reg': 2.5070017628420787, 'bagging_temperature': 0.9839447725188096, 'border_count': 150}. Best is trial 10 with value: 0.10820982514571187.
# [I 2025-05-28 17:17:09,189] Trial 11 finished with value: 0.10827643630308081 and parameters: {'depth': 10, 'lr': 0.05851159982543576, 'l2_leaf_reg': 2.450723611525486, 'bagging_temperature': 0.9306367457587595, 'border_count': 158}. Best is trial 10 with value: 0.10820982514571187.
# [I 2025-05-28 17:17:19,766] Trial 12 finished with value: 0.10937552039966703 and parameters: {'depth': 9, 'lr': 0.05658968424633625, 'l2_leaf_reg': 2.1804770058801095, 'bagging_temperature': 0.9752349957919536, 'border_count': 121}. Best is trial 10 with value: 0.10820982514571187.
# [I 2025-05-28 17:17:39,306] Trial 13 finished with value: 0.10704412989175682 and parameters: {'depth': 10, 'lr': 0.03855730170926132, 'l2_leaf_reg': 1.8207724528802853, 'bagging_temperature': 0.9979327661380321, 'border_count': 180}. Best is trial 13 with value: 0.10704412989175682.
# [I 2025-05-28 17:17:48,584] Trial 14 finished with value: 0.11203996669442129 and parameters: {'depth': 8, 'lr': 0.03557669524530882, 'l2_leaf_reg': 1.6405354812522117, 'bagging_temperature': 0.8350518175753154, 'border_count': 186}. Best is trial 13 with value: 0.10704412989175682.
# [I 2025-05-28 17:17:55,868] Trial 15 finished with value: 0.10957535387177353 and parameters: {'depth': 8, 'lr': 0.08593002648272816, 'l2_leaf_reg': 1.679393139966151, 'bagging_temperature': 0.7859791828699773, 'border_count': 126}. Best is trial 13 with value: 0.10704412989175682.
# [I 2025-05-28 17:18:07,828] Trial 16 finished with value: 0.11437135720233138 and parameters: {'depth': 10, 'lr': 0.011665054617790273, 'l2_leaf_reg': 3.291549188101355, 'bagging_temperature': 0.9912492344060244, 'border_count': 190}. Best is trial 13 with value: 0.10704412989175682.
# [I 2025-05-28 17:18:15,788] Trial 17 finished with value: 0.1131390507910075 and parameters: {'depth': 7, 'lr': 0.03206968254755005, 'l2_leaf_reg': 1.6478664479576095, 'bagging_temperature': 0.23891491575324608, 'border_count': 143}. Best is trial 13 with value: 0.10704412989175682.
# [I 2025-05-28 17:18:21,949] Trial 18 finished with value: 0.10870940882597824 and parameters: {'depth': 9, 'lr': 0.27684737624729944, 'l2_leaf_reg': 3.6137425923307576, 'bagging_temperature': 0.8648996609972136, 'border_count': 75}. Best is trial 13 with value: 0.10704412989175682.
# [I 2025-05-28 17:18:30,317] Trial 19 finished with value: 0.11120732722731064 and parameters: {'depth': 8, 'lr': 0.08044485557968895, 'l2_leaf_reg': 2.0403824933250596, 'bagging_temperature': 0.7046275856250523, 'border_count': 248}. Best is trial 13 with value: 0.10704412989175682.
# [I 2025-05-28 17:18:49,927] Trial 20 finished with value: 0.10681099084096579 and parameters: {'depth': 10, 'lr': 0.04211857619836945, 'l2_leaf_reg': 1.4212551470825923, 'bagging_temperature': 0.8980651122974416, 'border_count': 160}. Best is trial 20 with value: 0.10681099084096579.
# [I 2025-05-28 17:19:10,865] Trial 21 finished with value: 0.10667776852622812 and parameters: {'depth': 10, 'lr': 0.03834045309622297, 'l2_leaf_reg': 1.3707752980598544, 'bagging_temperature': 0.8886283558538698, 'border_count': 167}. Best is trial 21 with value: 0.10667776852622812.
# [I 2025-05-28 17:19:22,441] Trial 22 finished with value: 0.10950874271440458 and parameters: {'depth': 9, 'lr': 0.03962734800175214, 'l2_leaf_reg': 1.3260089114847013, 'bagging_temperature': 0.8798276278005982, 'border_count': 177}. Best is trial 21 with value: 0.10667776852622812.
# [I 2025-05-28 17:19:43,992] Trial 23 finished with value: 0.10830974188176534 and parameters: {'depth': 10, 'lr': 0.02529457367522211, 'l2_leaf_reg': 1.3589074081436527, 'bagging_temperature': 0.7967258002316719, 'border_count': 202}. Best is trial 21 with value: 0.10667776852622812.
# [I 2025-05-28 17:19:55,793] Trial 24 finished with value: 0.10957535387177353 and parameters: {'depth': 9, 'lr': 0.043609953231572046, 'l2_leaf_reg': 1.3184897415732524, 'bagging_temperature': 0.8875729062019977, 'border_count': 169}. Best is trial 21 with value: 0.10667776852622812.
# [I 2025-05-28 17:20:16,560] Trial 25 finished with value: 0.10904246461282252 and parameters: {'depth': 10, 'lr': 0.01605089423273937, 'l2_leaf_reg': 1.8722448765229647, 'bagging_temperature': 0.7023516348828565, 'border_count': 136}. Best is trial 21 with value: 0.10667776852622812.
# [I 2025-05-28 17:20:25,813] Trial 26 finished with value: 0.11030807660283093 and parameters: {'depth': 9, 'lr': 0.04593895574117508, 'l2_leaf_reg': 1.416340940224884, 'bagging_temperature': 0.9293424968804544, 'border_count': 203}. Best is trial 21 with value: 0.10667776852622812.
# [I 2025-05-28 17:20:32,446] Trial 27 finished with value: 0.1111407160699418 and parameters: {'depth': 8, 'lr': 0.08014046927603187, 'l2_leaf_reg': 2.796433523454237, 'bagging_temperature': 0.30474603855856996, 'border_count': 107}. Best is trial 21 with value: 0.10667776852622812.
# [I 2025-05-28 17:20:37,325] Trial 28 finished with value: 0.11920066611157354 and parameters: {'depth': 6, 'lr': 0.024793849497745497, 'l2_leaf_reg': 1.2274996330975811, 'bagging_temperature': 0.7807129655801137, 'border_count': 166}. Best is trial 21 with value: 0.10667776852622812.
# [I 2025-05-28 17:20:56,725] Trial 29 finished with value: 0.10930890924229808 and parameters: {'depth': 10, 'lr': 0.02883311677461679, 'l2_leaf_reg': 1.5946357372344575, 'bagging_temperature': 0.6596759354156255, 'border_count': 255}. Best is trial 21 with value: 0.10667776852622812.
# [I 2025-05-28 17:21:03,037] Trial 30 finished with value: 0.11557035803497084 and parameters: {'depth': 6, 'lr': 0.043861397161358825, 'l2_leaf_reg': 1.8986116675574307, 'bagging_temperature': 0.9220581397622433, 'border_count': 199}. Best is trial 21 with value: 0.10667776852622812.
# [I 2025-05-28 17:21:20,274] Trial 31 finished with value: 0.10544546211490435 and parameters: {'depth': 10, 'lr': 0.0684726764578326, 'l2_leaf_reg': 2.18456293400133, 'bagging_temperature': 0.9837122454050633, 'border_count': 150}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:21:30,664] Trial 32 finished with value: 0.10777685262281422 and parameters: {'depth': 10, 'lr': 0.19999271947022002, 'l2_leaf_reg': 2.171154478044243, 'bagging_temperature': 0.8378794100726024, 'border_count': 177}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:21:39,767] Trial 33 finished with value: 0.10997502081598687 and parameters: {'depth': 9, 'lr': 0.07144258322116323, 'l2_leaf_reg': 1.522671389547424, 'bagging_temperature': 0.937190829584898, 'border_count': 131}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:21:58,833] Trial 34 finished with value: 0.10990840965861781 and parameters: {'depth': 10, 'lr': 0.01848873809233524, 'l2_leaf_reg': 1.188232504181405, 'bagging_temperature': 0.9775802649778436, 'border_count': 150}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:22:03,850] Trial 35 finished with value: 0.12006661115736894 and parameters: {'depth': 4, 'lr': 0.06637657887564079, 'l2_leaf_reg': 1.0147037727987525, 'bagging_temperature': 0.8537671762851611, 'border_count': 121}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:22:13,755] Trial 36 finished with value: 0.10910907577019147 and parameters: {'depth': 9, 'lr': 0.046852056375897316, 'l2_leaf_reg': 1.7733336850644232, 'bagging_temperature': 0.7531598125401244, 'border_count': 36}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:22:25,002] Trial 37 finished with value: 0.11030807660283093 and parameters: {'depth': 10, 'lr': 0.10533862110405819, 'l2_leaf_reg': 3.0159754638276963, 'bagging_temperature': 0.9997383521321237, 'border_count': 88}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:22:35,615] Trial 38 finished with value: 0.10820982514571187 and parameters: {'depth': 10, 'lr': 0.17836720197159514, 'l2_leaf_reg': 2.3184537770515963, 'bagging_temperature': 0.5648368372207759, 'border_count': 168}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:22:45,218] Trial 39 finished with value: 0.11373855120732723 and parameters: {'depth': 8, 'lr': 0.0360988711430758, 'l2_leaf_reg': 4.266962326408625, 'bagging_temperature': 0.9116286766452688, 'border_count': 187}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:22:56,634] Trial 40 finished with value: 0.11230641132389674 and parameters: {'depth': 9, 'lr': 0.020892108023819318, 'l2_leaf_reg': 1.1816653410807183, 'bagging_temperature': 0.020627613480443174, 'border_count': 212}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:23:06,274] Trial 41 finished with value: 0.10850957535387185 and parameters: {'depth': 10, 'lr': 0.1972063283564828, 'l2_leaf_reg': 2.063769605246376, 'bagging_temperature': 0.8317615468325255, 'border_count': 175}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:23:16,140] Trial 42 finished with value: 0.10947543713572028 and parameters: {'depth': 10, 'lr': 0.21788137315066222, 'l2_leaf_reg': 1.4537206074741997, 'bagging_temperature': 0.8428990472840899, 'border_count': 155}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:23:27,660] Trial 43 finished with value: 0.10810990840965862 and parameters: {'depth': 10, 'lr': 0.1559985935940064, 'l2_leaf_reg': 1.9883772944919071, 'bagging_temperature': 0.9500282145334201, 'border_count': 141}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:23:39,630] Trial 44 finished with value: 0.11004163197335559 and parameters: {'depth': 9, 'lr': 0.031427462854252554, 'l2_leaf_reg': 2.2708643622216265, 'bagging_temperature': 0.721617461851188, 'border_count': 162}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:23:51,778] Trial 45 finished with value: 0.10737718567860122 and parameters: {'depth': 10, 'lr': 0.10369582581276234, 'l2_leaf_reg': 2.679856414636973, 'bagging_temperature': 0.7996475027705956, 'border_count': 179}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:23:57,125] Trial 46 finished with value: 0.11620316402997499 and parameters: {'depth': 5, 'lr': 0.09612374565957686, 'l2_leaf_reg': 6.171928586220782, 'bagging_temperature': 0.43691929103642807, 'border_count': 191}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:24:12,597] Trial 47 finished with value: 0.107910074937552 and parameters: {'depth': 10, 'lr': 0.06772535228712079, 'l2_leaf_reg': 2.8625738831457173, 'bagging_temperature': 0.8952745897884521, 'border_count': 111}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:24:23,869] Trial 48 finished with value: 0.10967527060782678 and parameters: {'depth': 9, 'lr': 0.05336788354953344, 'l2_leaf_reg': 3.367380333906809, 'bagging_temperature': 0.8117521679660756, 'border_count': 151}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:24:35,750] Trial 49 finished with value: 0.10647793505412151 and parameters: {'depth': 10, 'lr': 0.11732511549921502, 'l2_leaf_reg': 2.4573848811145518, 'bagging_temperature': 0.14375079688545878, 'border_count': 229}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:24:44,542] Trial 50 finished with value: 0.10900915903413821 and parameters: {'depth': 9, 'lr': 0.1266925995697111, 'l2_leaf_reg': 1.7987015454661868, 'bagging_temperature': 0.3581567898770933, 'border_count': 239}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:24:56,164] Trial 51 finished with value: 0.10800999167360525 and parameters: {'depth': 10, 'lr': 0.0879021180225729, 'l2_leaf_reg': 2.5639012087962736, 'bagging_temperature': 0.9599968741659334, 'border_count': 229}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:25:08,917] Trial 52 finished with value: 0.10754371357202341 and parameters: {'depth': 10, 'lr': 0.11546301841311446, 'l2_leaf_reg': 2.354195399913134, 'bagging_temperature': 0.1763990122332295, 'border_count': 215}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:25:24,950] Trial 53 finished with value: 0.10774354704412992 and parameters: {'depth': 10, 'lr': 0.05400959603486471, 'l2_leaf_reg': 3.9759326016746326, 'bagging_temperature': 0.5119374204239633, 'border_count': 184}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:25:42,970] Trial 54 finished with value: 0.10880932556203171 and parameters: {'depth': 10, 'lr': 0.03751946764487737, 'l2_leaf_reg': 2.693862025719384, 'bagging_temperature': 0.19815214857055546, 'border_count': 145}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:25:51,373] Trial 55 finished with value: 0.10854288093255637 and parameters: {'depth': 9, 'lr': 0.145833597814959, 'l2_leaf_reg': 1.1099762396237378, 'bagging_temperature': 0.09782725605307009, 'border_count': 196}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:26:03,690] Trial 56 finished with value: 0.10910907577019147 and parameters: {'depth': 10, 'lr': 0.10195397967660835, 'l2_leaf_reg': 1.710660359826179, 'bagging_temperature': 0.8795279354272447, 'border_count': 161}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:26:15,710] Trial 57 finished with value: 0.10864279766860963 and parameters: {'depth': 9, 'lr': 0.05005696489293942, 'l2_leaf_reg': 3.1059046934253853, 'bagging_temperature': 0.7613897567183561, 'border_count': 228}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:26:31,396] Trial 58 finished with value: 0.10597835137385514 and parameters: {'depth': 10, 'lr': 0.06117064531091074, 'l2_leaf_reg': 1.5584236940466114, 'bagging_temperature': 0.6584691202694573, 'border_count': 172}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:26:48,242] Trial 59 finished with value: 0.10674437968359707 and parameters: {'depth': 10, 'lr': 0.062294211664441865, 'l2_leaf_reg': 1.5042592242111437, 'bagging_temperature': 0.6593629014220488, 'border_count': 208}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:26:54,640] Trial 60 finished with value: 0.11367194004995829 and parameters: {'depth': 7, 'lr': 0.06318216141503159, 'l2_leaf_reg': 1.5301762842519078, 'bagging_temperature': 0.5792324981372584, 'border_count': 241}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:27:12,290] Trial 61 finished with value: 0.10621149042464617 and parameters: {'depth': 10, 'lr': 0.04064392490271975, 'l2_leaf_reg': 1.2765797290627094, 'bagging_temperature': 0.6470733536771806, 'border_count': 221}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:27:25,795] Trial 62 finished with value: 0.10681099084096579 and parameters: {'depth': 10, 'lr': 0.07377557528440168, 'l2_leaf_reg': 1.2768665261793608, 'bagging_temperature': 0.6383161866553303, 'border_count': 206}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:27:42,178] Trial 63 finished with value: 0.10657785179017476 and parameters: {'depth': 10, 'lr': 0.05942413900936466, 'l2_leaf_reg': 1.4302285029732962, 'bagging_temperature': 0.6651465707218491, 'border_count': 225}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:27:55,853] Trial 64 finished with value: 0.10757701915070772 and parameters: {'depth': 10, 'lr': 0.059549651085802964, 'l2_leaf_reg': 1.1206371606276937, 'bagging_temperature': 0.6870381402569544, 'border_count': 221}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:28:11,382] Trial 65 finished with value: 0.1098751040799335 and parameters: {'depth': 10, 'lr': 0.02833223148280691, 'l2_leaf_reg': 1.4854372802823335, 'bagging_temperature': 0.4759460528118755, 'border_count': 238}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:28:20,329] Trial 66 finished with value: 0.10897585345545369 and parameters: {'depth': 9, 'lr': 0.07679021332265927, 'l2_leaf_reg': 1.3635169761017685, 'bagging_temperature': 0.5485463867557305, 'border_count': 224}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:28:36,408] Trial 67 finished with value: 0.10694421315570357 and parameters: {'depth': 10, 'lr': 0.04944133682493023, 'l2_leaf_reg': 1.5914723815961134, 'bagging_temperature': 0.6151961481247932, 'border_count': 213}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:28:53,331] Trial 68 finished with value: 0.10721065778517913 and parameters: {'depth': 10, 'lr': 0.0857861659128459, 'l2_leaf_reg': 9.929552355509102, 'bagging_temperature': 0.657998108968668, 'border_count': 235}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:29:02,799] Trial 69 finished with value: 0.10894254787676938 and parameters: {'depth': 9, 'lr': 0.060092463394466264, 'l2_leaf_reg': 1.2612676909902134, 'bagging_temperature': 0.6779492810053358, 'border_count': 249}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:29:15,806] Trial 70 finished with value: 0.10827643630308081 and parameters: {'depth': 10, 'lr': 0.0419218636722448, 'l2_leaf_reg': 1.0232208227251391, 'bagging_temperature': 0.6057832486700147, 'border_count': 194}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:29:36,263] Trial 71 finished with value: 0.10604496253122397 and parameters: {'depth': 10, 'lr': 0.040687543059632604, 'l2_leaf_reg': 1.3570812262471619, 'bagging_temperature': 0.5418225992396335, 'border_count': 208}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:29:51,394] Trial 72 finished with value: 0.10754371357202319 and parameters: {'depth': 10, 'lr': 0.05211802813420809, 'l2_leaf_reg': 1.1795092680712576, 'bagging_temperature': 0.47634615604359143, 'border_count': 208}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:30:04,310] Trial 73 finished with value: 0.10894254787676938 and parameters: {'depth': 10, 'lr': 0.03268423165521783, 'l2_leaf_reg': 1.3696497342139582, 'bagging_temperature': 0.5385958385605991, 'border_count': 218}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:30:19,535] Trial 74 finished with value: 0.10870940882597835 and parameters: {'depth': 10, 'lr': 0.039834803957534984, 'l2_leaf_reg': 1.6838132371940056, 'bagging_temperature': 0.6356899436884375, 'border_count': 228}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:30:34,957] Trial 75 finished with value: 0.10774354704412992 and parameters: {'depth': 10, 'lr': 0.06818189015103124, 'l2_leaf_reg': 1.9270527820320376, 'bagging_temperature': 0.4027822025796101, 'border_count': 247}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:30:48,935] Trial 76 finished with value: 0.10904246461282274 and parameters: {'depth': 9, 'lr': 0.0345816245512188, 'l2_leaf_reg': 1.5741981022431573, 'bagging_temperature': 0.7116112391369758, 'border_count': 200}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:31:04,937] Trial 77 finished with value: 0.10597835137385514 and parameters: {'depth': 10, 'lr': 0.04544457740464009, 'l2_leaf_reg': 1.4323286861388742, 'bagging_temperature': 0.7446363718773454, 'border_count': 233}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:31:18,549] Trial 78 finished with value: 0.10757701915070772 and parameters: {'depth': 10, 'lr': 0.04756633413979785, 'l2_leaf_reg': 2.1170698679845668, 'bagging_temperature': 0.7407781013674521, 'border_count': 232}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:31:27,498] Trial 79 finished with value: 0.1131057452123232 and parameters: {'depth': 8, 'lr': 0.029721839461727833, 'l2_leaf_reg': 1.280700017639252, 'bagging_temperature': 0.5901156803577998, 'border_count': 254}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:31:35,711] Trial 80 finished with value: 0.11693588676103239 and parameters: {'depth': 9, 'lr': 0.010273352478631871, 'l2_leaf_reg': 1.4132888469087777, 'bagging_temperature': 0.324088860728853, 'border_count': 243}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:31:53,415] Trial 81 finished with value: 0.10594504579517072 and parameters: {'depth': 10, 'lr': 0.04248099246823131, 'l2_leaf_reg': 1.4911114488008401, 'bagging_temperature': 0.6703054581649692, 'border_count': 221}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:32:09,063] Trial 82 finished with value: 0.1077102414654455 and parameters: {'depth': 10, 'lr': 0.044340381471243, 'l2_leaf_reg': 1.130005498557746, 'bagging_temperature': 0.6798122696405329, 'border_count': 235}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:32:25,653] Trial 83 finished with value: 0.1069775187343881 and parameters: {'depth': 10, 'lr': 0.040113475891673515, 'l2_leaf_reg': 1.757341498223661, 'bagging_temperature': 0.7745601923159021, 'border_count': 221}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:32:40,864] Trial 84 finished with value: 0.10761032472939225 and parameters: {'depth': 10, 'lr': 0.05545812603441764, 'l2_leaf_reg': 1.3216797441501145, 'bagging_temperature': 0.7350647621574294, 'border_count': 171}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:32:45,359] Trial 85 finished with value: 0.11920066611157376 and parameters: {'depth': 5, 'lr': 0.03509016165399543, 'l2_leaf_reg': 1.214525473463697, 'bagging_temperature': 0.6293154774025226, 'border_count': 224}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:33:06,530] Trial 86 finished with value: 0.10744379683596994 and parameters: {'depth': 10, 'lr': 0.027592689675166364, 'l2_leaf_reg': 1.4475065764716768, 'bagging_temperature': 0.569339181186209, 'border_count': 216}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:33:19,926] Trial 87 finished with value: 0.10854288093255637 and parameters: {'depth': 10, 'lr': 0.0465274679089963, 'l2_leaf_reg': 1.8811026053541628, 'bagging_temperature': 0.7024424621669326, 'border_count': 134}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:33:34,745] Trial 88 finished with value: 0.1077102414654455 and parameters: {'depth': 10, 'lr': 0.03881950274225333, 'l2_leaf_reg': 1.0586323859548266, 'bagging_temperature': 0.5376154365324355, 'border_count': 231}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:33:46,626] Trial 89 finished with value: 0.10830974188176512 and parameters: {'depth': 9, 'lr': 0.04234307607459835, 'l2_leaf_reg': 1.654194975736776, 'bagging_temperature': 0.816336257353727, 'border_count': 211}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:33:49,158] Trial 90 finished with value: 0.12889258950874272 and parameters: {'depth': 4, 'lr': 0.024188948922806715, 'l2_leaf_reg': 1.399450199068128, 'bagging_temperature': 0.4890108661362521, 'border_count': 185}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:34:05,555] Trial 91 finished with value: 0.10697751873438788 and parameters: {'depth': 10, 'lr': 0.06372765708580383, 'l2_leaf_reg': 1.5034614559030859, 'bagging_temperature': 0.6518171804624713, 'border_count': 204}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:34:22,238] Trial 92 finished with value: 0.10671107410491254 and parameters: {'depth': 10, 'lr': 0.05707440378632365, 'l2_leaf_reg': 1.5836061190028852, 'bagging_temperature': 0.6702428770765898, 'border_count': 210}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:34:43,353] Trial 93 finished with value: 0.10547876769358877 and parameters: {'depth': 10, 'lr': 0.05192249080908034, 'l2_leaf_reg': 2.4313887055217585, 'bagging_temperature': 0.6044853452225031, 'border_count': 219}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:35:01,501] Trial 94 finished with value: 0.10634471273938373 and parameters: {'depth': 10, 'lr': 0.04790374331622591, 'l2_leaf_reg': 2.490705860131701, 'bagging_temperature': 0.5944504708623759, 'border_count': 222}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:35:19,153] Trial 95 finished with value: 0.105745212323064 and parameters: {'depth': 10, 'lr': 0.05014842898785056, 'l2_leaf_reg': 2.5046836109024966, 'bagging_temperature': 0.588971610810904, 'border_count': 217}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:35:38,300] Trial 96 finished with value: 0.10651124063280604 and parameters: {'depth': 10, 'lr': 0.05115924118555013, 'l2_leaf_reg': 2.411186446421087, 'bagging_temperature': 0.6014678938315857, 'border_count': 218}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:35:56,835] Trial 97 finished with value: 0.10674437968359707 and parameters: {'depth': 10, 'lr': 0.04492634709339889, 'l2_leaf_reg': 2.517067167188124, 'bagging_temperature': 0.5268470158569456, 'border_count': 234}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:36:07,636] Trial 98 finished with value: 0.11160699417152387 and parameters: {'depth': 9, 'lr': 0.03290896733098722, 'l2_leaf_reg': 2.780155975013295, 'bagging_temperature': 0.5829105146637971, 'border_count': 244}. Best is trial 31 with value: 0.10544546211490435.
# [I 2025-05-28 17:36:27,382] Trial 99 finished with value: 0.1070108243130724 and parameters: {'depth': 10, 'lr': 0.048313482478460304, 'l2_leaf_reg': 2.934606949591558, 'bagging_temperature': 0.6391868324182428, 'border_count': 196}. Best is trial 31 with value: 0.10544546211490435.

# %%
print("LGB Best Acc:", 1-study_lgb.best_value, study_lgb.best_params)
print("XGB Best Acc:", 1-study_xgb.best_value, study_xgb.best_params)
print("CAT Best Acc:", 1-study_cat.best_value, study_cat.best_params)
# Out:
# LGB Best Acc: 0.8984845961698584 {'lr': 0.045396498700576694, 'num_leaves': 125, 'max_depth': 12, 'feature_fraction': 0.5184870762616136, 'bagging_fraction': 0.7293550235168924, 'bagging_freq': 1, 'lambda_l1': 0.43956960476577256, 'lambda_l2': 0.9219797780232823}
# XGB Best Acc: 0.9003164029975022 {'lr': 0.032532111147427586, 'max_depth': 11, 'subsample': 0.8970969017618952, 'colsample_bytree': 0.5179945005269921, 'gamma': 0.016508932515318583, 'min_child_weight': 1, 'reg_lambda': 0.2715947195109578}
# CAT Best Acc: 0.8945545378850956 {'depth': 10, 'lr': 0.0684726764578326, 'l2_leaf_reg': 2.18456293400133, 'bagging_temperature': 0.9837122454050633, 'border_count': 150}

# %%
# ===============================
# 8. 스태킹 앙상블 학습
# ===============================
lgb_best = LGBMClassifier(**study_lgb.best_params, n_estimators=400, random_state=SEED)
xgb_best = XGBClassifier(**study_xgb.best_params, n_estimators=400, random_state=SEED, tree_method='hist', verbosity=0)
cat_p    = study_cat.best_params.copy()
cat_p['learning_rate'] = cat_p.pop('lr')
cat_best = CatBoostClassifier(**cat_p, iterations=400, random_seed=SEED, verbose=False)

meta = LGBMClassifier(objective='binary', n_estimators=200, learning_rate=0.05,
                      num_leaves=31, random_state=SEED)

stack = StackingClassifier(
    estimators=[('lgb',lgb_best),('xgb',xgb_best),('cat',cat_best)],
    final_estimator=meta, cv=skf, n_jobs=-1
)
stack.fit(X_tr, y_tr)
# Out:
# [LightGBM] [Info] Number of positive: 23704, number of negative: 6321
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000555 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 764
# [LightGBM] [Info] Number of data points in the train set: 30025, number of used features: 3
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.789475 -> initscore=1.321766
# [LightGBM] [Info] Start training from score 1.321766
# StackingClassifier(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#                    estimators=[('lgb',
#                                 LGBMClassifier(bagging_fraction=0.7293550235168924,
#                                                bagging_freq=1,
#                                                feature_fraction=0.5184870762616136,
#                                                lambda_l1=0.43956960476577256,
#                                                lambda_l2=0.9219797780232823,
#                                                lr=0.045396498700576694,
#                                                max_depth=12, n_estimators=400,
#                                                num_leaves=125,
#                                                random_state=42)),
#                                ('xg...
#                                               max_delta_step=None, max_depth=11,
#                                               max_leaves=None,
#                                               min_child_weight=1, missing=nan,
#                                               monotone_constraints=None,
#                                               multi_strategy=None,
#                                               n_estimators=400, n_jobs=None,
#                                               num_parallel_tree=None, ...)),
#                                ('cat',
#                                 <catboost.core.CatBoostClassifier object at 0x7e667b3f4cd0>)],
#                    final_estimator=LGBMClassifier(learning_rate=0.05,
#                                                   n_estimators=200,
#                                                   objective='binary',
#                                                   random_state=42),
#                    n_jobs=-1)

# %%
# ===============================
# 9. 임계값 최적화
# ===============================
proba_va = stack.predict_proba(X_va)[:,1]
ths = np.linspace(0.1,0.9,81)
accs = [accuracy_score(y_va, (proba_va>t).astype(int)) for t in ths]
best_idx = np.argmax(accs)
best_thr = ths[best_idx]
print(f"Best val Acc {accs[best_idx]:.4f} at threshold {best_thr}")
# Out:
# [LightGBM] [Warning] Unknown parameter: lr
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] feature_fraction is set=0.5184870762616136, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5184870762616136
# [LightGBM] [Warning] lambda_l2 is set=0.9219797780232823, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.9219797780232823
# [LightGBM] [Warning] lambda_l1 is set=0.43956960476577256, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.43956960476577256
# [LightGBM] [Warning] bagging_fraction is set=0.7293550235168924, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7293550235168924
# Best val Acc 0.9039 at threshold 0.64

# %%
# ===============================
# 10. 모델·전처리기 저장
# ===============================
joblib.dump(iso,            f'{OUT_DIR}/iso_model.pkl')
joblib.dump(vt,             f'{OUT_DIR}/vt_model.pkl')
joblib.dump(scaler,         f'{OUT_DIR}/scaler.pkl')
joblib.dump(stack,          f'{OUT_DIR}/stack_model.pkl')
joblib.dump(selected_feats, f'{OUT_DIR}/selected_feats.pkl')
joblib.dump(best_thr,       f'{OUT_DIR}/best_threshold.pkl')
print("✅ All models saved to", OUT_DIR)
# Out:
# ✅ All models saved to /content/drive/MyDrive/25년 해군 AI 경진대회/model_result

# %%
# ===============================
# 11. 새 데이터 예측 및 제출 파일 생성
# ===============================
# 11-1) 전처리기·모델 로드
iso_loaded    = joblib.load(f'{OUT_DIR}/iso_model.pkl')       # (학습때만 사용)
vt_loaded     = joblib.load(f'{OUT_DIR}/vt_model.pkl')
scaler_loaded = joblib.load(f'{OUT_DIR}/scaler.pkl')
stack_loaded  = joblib.load(f'{OUT_DIR}/stack_model.pkl')
feats_loaded  = joblib.load(f'{OUT_DIR}/selected_feats.pkl')
thr_loaded    = joblib.load(f'{OUT_DIR}/best_threshold.pkl')

# %%
# 11-2) 신규 AIS 데이터
NEW_FILE = '/content/20240701(1번문제).csv'
raw_new  = pd.read_csv(NEW_FILE)

# 11-3) 피처 엔지니어링
feat_new = aggregate_ais(raw_new)
feat_new['rule_score'] = feat_new.apply(rule_score, axis=1)

# 11-4) 예측용 행렬 생성
Xn = feat_new[feat_cols].values
Xn = scaler_loaded.transform(Xn)
Xn = vt_loaded.transform(Xn)

# 11-5) 예측 & 임계값 적용
proba = stack_loaded.predict_proba(Xn)[:,1]
feat_new['result'] = np.where(proba>thr_loaded, 'TRUE','FALSE')

# 11-6) 제출 파일 저장
submission = feat_new[['MMSI','result']]
submission.to_csv(f'{OUT_DIR}/submission_ver5.csv', index=False)
print("✅ submission.csv saved to", OUT_DIR)
# Out:
# [LightGBM] [Warning] Unknown parameter: lr
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] feature_fraction is set=0.5184870762616136, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5184870762616136
# [LightGBM] [Warning] lambda_l2 is set=0.9219797780232823, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.9219797780232823
# [LightGBM] [Warning] lambda_l1 is set=0.43956960476577256, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.43956960476577256
# [LightGBM] [Warning] bagging_fraction is set=0.7293550235168924, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7293550235168924
# ✅ submission.csv saved to /content/drive/MyDrive/25년 해군 AI 경진대회/model_result
