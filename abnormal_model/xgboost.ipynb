# %%
# =======================================================
# =======================================================
# !pip install --quiet xgboost==2.0.3 scikit-learn==1.4.2 pandas==2.2.2 \
                 geopandas shapely pyproj fiona

from google.colab import drive
drive.mount('/content/drive')

import os, datetime, json, joblib, pandas as pd, geopandas as gpd
from shapely.geometry import Polygon, box
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score, precision_recall_fscore_support,
    roc_auc_score, confusion_matrix
)
from xgboost import XGBClassifier
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 116.5 MB/s eta 0:00:00
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# -------------------------------------------------------
# -------------------------------------------------------
DATA_PATH = '/content/drive/MyDrive/25년 해군 AI 경진대회/combined_ais_20230601_20240531.csv'
ZONE_DIR  = '/content/drive/MyDrive/25년 해군 AI 경진대회/dataset/구역 데이터'
MODEL_DIR = '/content/drive/MyDrive/25년 해군 AI 경진대회/model_result'
os.makedirs(MODEL_DIR, exist_ok=True)

zone_files = [
    ('Area_Navy_train.csv'                   , 'navy_train'),
    ('Area_Near_Sea.csv'                     , 'near_sea'),
    ('Area_Restrict_zone.csv'                , 'restrict'),
    ('Area_Sea_cable_lv1_poly.csv'           , 'sea_cable'),
    ('Area_Special_restrict_zone_poly.csv'   , 'special_restrict'),
    ('Area_Target_Area.csv'                  , 'target_area')
]

# %%
def load_zone_csv(file_path: str, label: str) -> gpd.GeoDataFrame:
    """
    CSV → Polygon(s)
    - 필수: LON, LAT  (대·소문자 허용)
    - 그룹 컬럼: OBJNUM* 계열 → 여러 다각형, 없으면 파일 전체 하나로 처리
    - Polygon 생성 실패 시 convex_hull 대체, 그래도 불가하면 스킵
    """
    df = pd.read_csv(file_path)

    # ① 좌표 컬럼 찾기
    lon_col = next(c for c in df.columns if c.lower() == 'lon')
    lat_col = next(c for c in df.columns if c.lower() == 'lat')

    # ② 그룹 컬럼 찾기
    grp_candidates = [c for c in df.columns if c.lower().startswith('obj')]
    group_col = grp_candidates[0] if grp_candidates else None

    polygons = []
    groups = df.groupby(group_col) if group_col else [('single', df)]
    for gid, grp in groups:
        coords = list(zip(grp[lon_col].values, grp[lat_col].values))
        if len(coords) < 3:
            print(f'⚠️  {os.path.basename(file_path)} - {gid}: 꼭짓점<3 → 건너뜀')
            continue
        if coords[0] != coords[-1]:
            coords.append(coords[0])

        poly = None
        try:
            poly = Polygon(coords)
            if not poly.is_valid:
                poly = poly.buffer(0)         # 자가교차 등 교정
        except Exception:
            pass

        # fallback: convex hull
        if (poly is None) or poly.is_empty or (not poly.is_valid):
            poly = gpd.GeoSeries([Polygon(coords)]).unary_union.convex_hull

        if poly.is_valid and (not poly.is_empty) and poly.area > 0:
            polygons.append(poly)
        else:
            print(f'⚠️  {os.path.basename(file_path)} - {gid}: 유효 Polygon 생성 실패')

    if not polygons:
        print(f'❗ {os.path.basename(file_path)}: usable Polygon 없음 → 파일 건너뜀')
        return gpd.GeoDataFrame(columns=['zone_type', 'geometry'], crs='EPSG:4326')

    return gpd.GeoDataFrame(
        {'zone_type': [label] * len(polygons), 'geometry': polygons},
        crs='EPSG:4326'
    )

# %%
zone_gdfs = [
    load_zone_csv(os.path.join(ZONE_DIR, fname), lbl)
    for fname, lbl in zone_files
]

# 빈 GeoDataFrame 은 자동으로 걸러냄
zones_gdf = pd.concat([g for g in zone_gdfs if not g.empty], ignore_index=True)
print('Zone polygons loaded:', len(zones_gdf))
zones_sindex = zones_gdf.sindex
# Out:
# Zone polygons loaded: 244

# %%
# -------------------------------------------------------
# 3. AIS 집계 데이터 로드 & BBox GeoDataFrame ------------
# -------------------------------------------------------
ais_df = pd.read_csv(DATA_PATH)
print('AIS rows:', len(ais_df))

bbox_polys = [
    box(min(lon1, lon2), min(lat1, lat2), max(lon1, lon2), max(lat1, lat2))
    for lon1, lon2, lat1, lat2 in zip(
        ais_df['min_lon'], ais_df['max_lon'], ais_df['min_lat'], ais_df['max_lat'])
]
ais_gdf = gpd.GeoDataFrame(ais_df, geometry=bbox_polys, crs='EPSG:4326')
# Out:
# AIS rows: 2678129

# %%
# -------------------------------------------------------
# 4. 구역 교차 Feature (벡터화·수정) ---------------------
# -------------------------------------------------------

# 4-1) spatial join
join_df = gpd.sjoin(
    ais_gdf[['geometry']],                 # 왼쪽: AIS BBox
    zones_gdf[['zone_type', 'geometry']],  # 오른쪽: Zones
    how='left',
    predicate='intersects'
).reset_index().rename(columns={'index': 'ais_idx'})
# └─ 이제 'ais_idx' 가 AIS 원본 행번호

# 4-2) zone_type × count pivot
pivot = (
    join_df.dropna(subset=['zone_type'])
           .assign(hit=1)
           .pivot_table(index='ais_idx', columns='zone_type',
                        values='hit', aggfunc='sum', fill_value=0)
)

# 4-3) in_{zone}, num_zone_hits
ais_gdf['num_zone_hits'] = (
    pivot.sum(axis=1)
         .reindex(ais_gdf.index, fill_value=0)
         .astype(int)
)

for z in zones_gdf['zone_type'].unique():
    ais_gdf[f'in_{z}'] = (
        (pivot.get(z, 0) > 0)
        .reindex(ais_gdf.index, fill_value=0)
        .astype(int)
)

print('⚡ 공간 feature 생성 완료 (vectorized)')
# Out:
# ⚡ 공간 feature 생성 완료 (vectorized)

# %%
# -------------------------------------------------------
# 5. X / y 전처리 ---------------------------------------
# -------------------------------------------------------
def prepare_xy(df, drop_cols=None):
    if drop_cols is None:
        drop_cols = []
    df = df.copy()

    # y 변환 (True/False → 1/0)
    if 'label' in df.columns and 'result' not in df.columns:
        df.rename(columns={'label': 'result'}, inplace=True)
    df['result'] = (
        df['result'].astype(str).str.lower()
          .map({'true':1, 'false':0, '1':1, '0':0})
          .astype(int)
    )

    # 날짜(object) 컬럼 → 숫자 파생
    for col in df.select_dtypes(include=['object']).columns:
        if col == 'result':
            continue
        try:
            dt = pd.to_datetime(df[col], errors='raise')
            df[f'{col}_doy'] = dt.dt.dayofyear
            df[f'{col}_dow'] = dt.dt.weekday
            df.drop(columns=[col], inplace=True)
        except (ValueError, TypeError):
            df.drop(columns=[col], inplace=True)  # 문자 컬럼이 남아있다면 삭제

    y = df['result']
    X = df.drop(columns=drop_cols + ['result'])
    return X, y

X, y = prepare_xy(ais_gdf.drop(columns=['geometry']), drop_cols=['MMSI'])
print('Feature matrix shape:', X.shape)
# Out:
# Feature matrix shape: (2678129, 34)

# %%
# -------------------------------------------------------
# 6. Stratified Split ----------------------------------
# -------------------------------------------------------
X_tmp, X_test, y_tmp, y_test = train_test_split(
    X, y, test_size=0.15, stratify=y, random_state=42)
val_ratio = 0.15 / 0.85
X_train, X_val, y_train, y_val = train_test_split(
    X_tmp, y_tmp, test_size=val_ratio, stratify=y_tmp, random_state=42)

# %%
# -------------------------------------------------------
# 7. XGBoost 학습 + Early-Stopping -----------------------
# -------------------------------------------------------
base_params = dict(
    objective='binary:logistic',
    n_estimators=5000,           # 크게 두고 early-stop
    learning_rate=0.05,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    reg_lambda=1.0,
    random_state=42,
    tree_method='hist',          # GPU: 'gpu_hist'
    enable_categorical=True,
    eval_metric=['logloss','auc'],
    early_stopping_rounds=100
)

# 1) best_iter 찾기 (train → val)
tmp_model = XGBClassifier(**base_params)
tmp_model.fit(X_train, y_train, eval_set=[(X_val, y_val)], verbose=True)
best_iter = tmp_model.best_iteration
print(f'◆ Early-stopped at round {best_iter}')

# 2) train+val 전체 데이터로 재학습 (best_iter 트리 수만)
final_params          = base_params.copy()
final_params.pop('n_estimators')
final_params.pop('early_stopping_rounds')

model = XGBClassifier(**final_params, n_estimators=best_iter)
model.fit(
    pd.concat([X_train, X_val]),
    pd.concat([y_train, y_val]),
    verbose=False
)
# Out:
# [0]	validation_0-logloss:0.62201	validation_0-auc:0.99814
# [1]	validation_0-logloss:0.58222	validation_0-auc:0.99766
# [2]	validation_0-logloss:0.54709	validation_0-auc:0.99870
# [3]	validation_0-logloss:0.51237	validation_0-auc:0.99882
# [4]	validation_0-logloss:0.48669	validation_0-auc:0.99843
# [5]	validation_0-logloss:0.45705	validation_0-auc:0.99860
# [6]	validation_0-logloss:0.43065	validation_0-auc:0.99862
# [7]	validation_0-logloss:0.40555	validation_0-auc:0.99880
# [8]	validation_0-logloss:0.38329	validation_0-auc:0.99879
# [9]	validation_0-logloss:0.36368	validation_0-auc:0.99872
# [10]	validation_0-logloss:0.34360	validation_0-auc:0.99880
# [11]	validation_0-logloss:0.32617	validation_0-auc:0.99881
# [12]	validation_0-logloss:0.30879	validation_0-auc:0.99886
# [13]	validation_0-logloss:0.29253	validation_0-auc:0.99894
# [14]	validation_0-logloss:0.27802	validation_0-auc:0.99893
# [15]	validation_0-logloss:0.26427	validation_0-auc:0.99892
# [16]	validation_0-logloss:0.25098	validation_0-auc:0.99901
# [17]	validation_0-logloss:0.23944	validation_0-auc:0.99908
# [18]	validation_0-logloss:0.22785	validation_0-auc:0.99913
# [19]	validation_0-logloss:0.21869	validation_0-auc:0.99916
# [20]	validation_0-logloss:0.20909	validation_0-auc:0.99923
# [21]	validation_0-logloss:0.20041	validation_0-auc:0.99922
# [22]	validation_0-logloss:0.19223	validation_0-auc:0.99926
# [23]	validation_0-logloss:0.18446	validation_0-auc:0.99927
# [24]	validation_0-logloss:0.17721	validation_0-auc:0.99926
# [25]	validation_0-logloss:0.16910	validation_0-auc:0.99929
# [26]	validation_0-logloss:0.16151	validation_0-auc:0.99930
# [27]	validation_0-logloss:0.15429	validation_0-auc:0.99931
# [28]	validation_0-logloss:0.14811	validation_0-auc:0.99933
# [29]	validation_0-logloss:0.14216	validation_0-auc:0.99934
# [30]	validation_0-logloss:0.13604	validation_0-auc:0.99935
# [31]	validation_0-logloss:0.13116	validation_0-auc:0.99936
# [32]	validation_0-logloss:0.12676	validation_0-auc:0.99938
# [33]	validation_0-logloss:0.12181	validation_0-auc:0.99937
# [34]	validation_0-logloss:0.11673	validation_0-auc:0.99938
# [35]	validation_0-logloss:0.11239	validation_0-auc:0.99938
# [36]	validation_0-logloss:0.10829	validation_0-auc:0.99938
# [37]	validation_0-logloss:0.10397	validation_0-auc:0.99939
# [38]	validation_0-logloss:0.10052	validation_0-auc:0.99939
# [39]	validation_0-logloss:0.09688	validation_0-auc:0.99939
# [40]	validation_0-logloss:0.09344	validation_0-auc:0.99939
# [41]	validation_0-logloss:0.09043	validation_0-auc:0.99940
# [42]	validation_0-logloss:0.08743	validation_0-auc:0.99940
# [43]	validation_0-logloss:0.08465	validation_0-auc:0.99942
# [44]	validation_0-logloss:0.08177	validation_0-auc:0.99942
# [45]	validation_0-logloss:0.07885	validation_0-auc:0.99943
# [46]	validation_0-logloss:0.07646	validation_0-auc:0.99942
# [47]	validation_0-logloss:0.07387	validation_0-auc:0.99943
# [48]	validation_0-logloss:0.07137	validation_0-auc:0.99943
# [49]	validation_0-logloss:0.06897	validation_0-auc:0.99943
# [50]	validation_0-logloss:0.06671	validation_0-auc:0.99944
# [51]	validation_0-logloss:0.06473	validation_0-auc:0.99946
# [52]	validation_0-logloss:0.06267	validation_0-auc:0.99946
# [53]	validation_0-logloss:0.06071	validation_0-auc:0.99947
# [54]	validation_0-logloss:0.05884	validation_0-auc:0.99947
# [55]	validation_0-logloss:0.05746	validation_0-auc:0.99947
# [56]	validation_0-logloss:0.05597	validation_0-auc:0.99949
# [57]	validation_0-logloss:0.05458	validation_0-auc:0.99949
# [58]	validation_0-logloss:0.05299	validation_0-auc:0.99949
# [59]	validation_0-logloss:0.05154	validation_0-auc:0.99950
# [60]	validation_0-logloss:0.05044	validation_0-auc:0.99950
# [61]	validation_0-logloss:0.04917	validation_0-auc:0.99950
# [62]	validation_0-logloss:0.04785	validation_0-auc:0.99950
# [63]	validation_0-logloss:0.04661	validation_0-auc:0.99951
# [64]	validation_0-logloss:0.04567	validation_0-auc:0.99951
# [65]	validation_0-logloss:0.04473	validation_0-auc:0.99952
# [66]	validation_0-logloss:0.04387	validation_0-auc:0.99953
# [67]	validation_0-logloss:0.04283	validation_0-auc:0.99953
# [68]	validation_0-logloss:0.04187	validation_0-auc:0.99953
# [69]	validation_0-logloss:0.04089	validation_0-auc:0.99954
# [70]	validation_0-logloss:0.03995	validation_0-auc:0.99954
# [71]	validation_0-logloss:0.03909	validation_0-auc:0.99954
# [72]	validation_0-logloss:0.03846	validation_0-auc:0.99954
# [73]	validation_0-logloss:0.03770	validation_0-auc:0.99954
# [74]	validation_0-logloss:0.03709	validation_0-auc:0.99955
# [75]	validation_0-logloss:0.03634	validation_0-auc:0.99955
# [76]	validation_0-logloss:0.03566	validation_0-auc:0.99955
# [77]	validation_0-logloss:0.03505	validation_0-auc:0.99956
# [78]	validation_0-logloss:0.03446	validation_0-auc:0.99957
# [79]	validation_0-logloss:0.03397	validation_0-auc:0.99957
# [80]	validation_0-logloss:0.03345	validation_0-auc:0.99957
# [81]	validation_0-logloss:0.03300	validation_0-auc:0.99958
# [82]	validation_0-logloss:0.03240	validation_0-auc:0.99958
# [83]	validation_0-logloss:0.03189	validation_0-auc:0.99959
# [84]	validation_0-logloss:0.03152	validation_0-auc:0.99959
# [85]	validation_0-logloss:0.03104	validation_0-auc:0.99960
# [86]	validation_0-logloss:0.03057	validation_0-auc:0.99960
# [87]	validation_0-logloss:0.03011	validation_0-auc:0.99961
# [88]	validation_0-logloss:0.02974	validation_0-auc:0.99961
# [89]	validation_0-logloss:0.02927	validation_0-auc:0.99962
# [90]	validation_0-logloss:0.02885	validation_0-auc:0.99962
# [91]	validation_0-logloss:0.02840	validation_0-auc:0.99962
# [92]	validation_0-logloss:0.02800	validation_0-auc:0.99962
# [93]	validation_0-logloss:0.02764	validation_0-auc:0.99963
# [94]	validation_0-logloss:0.02731	validation_0-auc:0.99963
# [95]	validation_0-logloss:0.02701	validation_0-auc:0.99963
# [96]	validation_0-logloss:0.02671	validation_0-auc:0.99964
# [97]	validation_0-logloss:0.02639	validation_0-auc:0.99964
# [98]	validation_0-logloss:0.02607	validation_0-auc:0.99964
# [99]	validation_0-logloss:0.02585	validation_0-auc:0.99965
# [100]	validation_0-logloss:0.02557	validation_0-auc:0.99965
# [101]	validation_0-logloss:0.02525	validation_0-auc:0.99965
# [102]	validation_0-logloss:0.02498	validation_0-auc:0.99965
# [103]	validation_0-logloss:0.02472	validation_0-auc:0.99966
# [104]	validation_0-logloss:0.02450	validation_0-auc:0.99966
# [105]	validation_0-logloss:0.02422	validation_0-auc:0.99967
# [106]	validation_0-logloss:0.02396	validation_0-auc:0.99967
# [107]	validation_0-logloss:0.02373	validation_0-auc:0.99967
# [108]	validation_0-logloss:0.02356	validation_0-auc:0.99967
# [109]	validation_0-logloss:0.02335	validation_0-auc:0.99968
# [110]	validation_0-logloss:0.02311	validation_0-auc:0.99968
# [111]	validation_0-logloss:0.02290	validation_0-auc:0.99968
# [112]	validation_0-logloss:0.02272	validation_0-auc:0.99968
# [113]	validation_0-logloss:0.02255	validation_0-auc:0.99969
# [114]	validation_0-logloss:0.02233	validation_0-auc:0.99969
# [115]	validation_0-logloss:0.02219	validation_0-auc:0.99969
# [116]	validation_0-logloss:0.02205	validation_0-auc:0.99969
# [117]	validation_0-logloss:0.02188	validation_0-auc:0.99969
# [118]	validation_0-logloss:0.02175	validation_0-auc:0.99969
# [119]	validation_0-logloss:0.02162	validation_0-auc:0.99970
# [120]	validation_0-logloss:0.02149	validation_0-auc:0.99970
# [121]	validation_0-logloss:0.02135	validation_0-auc:0.99970
# [122]	validation_0-logloss:0.02122	validation_0-auc:0.99970
# [123]	validation_0-logloss:0.02110	validation_0-auc:0.99970
# [124]	validation_0-logloss:0.02098	validation_0-auc:0.99970
# [125]	validation_0-logloss:0.02088	validation_0-auc:0.99971
# [126]	validation_0-logloss:0.02075	validation_0-auc:0.99971
# [127]	validation_0-logloss:0.02062	validation_0-auc:0.99971
# [128]	validation_0-logloss:0.02051	validation_0-auc:0.99971
# [129]	validation_0-logloss:0.02043	validation_0-auc:0.99971
# [130]	validation_0-logloss:0.02034	validation_0-auc:0.99972
# [131]	validation_0-logloss:0.02023	validation_0-auc:0.99972
# [132]	validation_0-logloss:0.02012	validation_0-auc:0.99972
# [133]	validation_0-logloss:0.01999	validation_0-auc:0.99972
# [134]	validation_0-logloss:0.01993	validation_0-auc:0.99972
# [135]	validation_0-logloss:0.01984	validation_0-auc:0.99973
# [136]	validation_0-logloss:0.01974	validation_0-auc:0.99973
# [137]	validation_0-logloss:0.01965	validation_0-auc:0.99973
# [138]	validation_0-logloss:0.01956	validation_0-auc:0.99973
# [139]	validation_0-logloss:0.01950	validation_0-auc:0.99973
# [140]	validation_0-logloss:0.01943	validation_0-auc:0.99973
# [141]	validation_0-logloss:0.01931	validation_0-auc:0.99974
# [142]	validation_0-logloss:0.01923	validation_0-auc:0.99974
# [143]	validation_0-logloss:0.01914	validation_0-auc:0.99974
# [144]	validation_0-logloss:0.01907	validation_0-auc:0.99974
# [145]	validation_0-logloss:0.01901	validation_0-auc:0.99974
# [146]	validation_0-logloss:0.01889	validation_0-auc:0.99975
# [147]	validation_0-logloss:0.01884	validation_0-auc:0.99975
# [148]	validation_0-logloss:0.01877	validation_0-auc:0.99975
# [149]	validation_0-logloss:0.01870	validation_0-auc:0.99975
# [150]	validation_0-logloss:0.01862	validation_0-auc:0.99975
# [151]	validation_0-logloss:0.01848	validation_0-auc:0.99976
# [152]	validation_0-logloss:0.01843	validation_0-auc:0.99976
# [153]	validation_0-logloss:0.01837	validation_0-auc:0.99976
# [154]	validation_0-logloss:0.01832	validation_0-auc:0.99976
# [155]	validation_0-logloss:0.01825	validation_0-auc:0.99976
# [156]	validation_0-logloss:0.01821	validation_0-auc:0.99976
# [157]	validation_0-logloss:0.01814	validation_0-auc:0.99976
# [158]	validation_0-logloss:0.01811	validation_0-auc:0.99977
# [159]	validation_0-logloss:0.01807	validation_0-auc:0.99977
# [160]	validation_0-logloss:0.01800	validation_0-auc:0.99977
# [161]	validation_0-logloss:0.01793	validation_0-auc:0.99977
# [162]	validation_0-logloss:0.01789	validation_0-auc:0.99977
# [163]	validation_0-logloss:0.01784	validation_0-auc:0.99977
# [164]	validation_0-logloss:0.01779	validation_0-auc:0.99977
# [165]	validation_0-logloss:0.01776	validation_0-auc:0.99977
# [166]	validation_0-logloss:0.01763	validation_0-auc:0.99978
# [167]	validation_0-logloss:0.01757	validation_0-auc:0.99978
# [168]	validation_0-logloss:0.01752	validation_0-auc:0.99978
# [169]	validation_0-logloss:0.01748	validation_0-auc:0.99978
# [170]	validation_0-logloss:0.01745	validation_0-auc:0.99978
# [171]	validation_0-logloss:0.01742	validation_0-auc:0.99978
# [172]	validation_0-logloss:0.01736	validation_0-auc:0.99979
# [173]	validation_0-logloss:0.01731	validation_0-auc:0.99979
# [174]	validation_0-logloss:0.01728	validation_0-auc:0.99979
# [175]	validation_0-logloss:0.01722	validation_0-auc:0.99979
# [176]	validation_0-logloss:0.01718	validation_0-auc:0.99979
# [177]	validation_0-logloss:0.01714	validation_0-auc:0.99979
# [178]	validation_0-logloss:0.01709	validation_0-auc:0.99979
# [179]	validation_0-logloss:0.01707	validation_0-auc:0.99979
# [180]	validation_0-logloss:0.01699	validation_0-auc:0.99979
# [181]	validation_0-logloss:0.01698	validation_0-auc:0.99979
# [182]	validation_0-logloss:0.01691	validation_0-auc:0.99980
# [183]	validation_0-logloss:0.01686	validation_0-auc:0.99980
# [184]	validation_0-logloss:0.01683	validation_0-auc:0.99980
# [185]	validation_0-logloss:0.01678	validation_0-auc:0.99980
# [186]	validation_0-logloss:0.01674	validation_0-auc:0.99980
# [187]	validation_0-logloss:0.01670	validation_0-auc:0.99980
# [188]	validation_0-logloss:0.01665	validation_0-auc:0.99980
# [189]	validation_0-logloss:0.01661	validation_0-auc:0.99980
# [190]	validation_0-logloss:0.01658	validation_0-auc:0.99980
# [191]	validation_0-logloss:0.01656	validation_0-auc:0.99980
# [192]	validation_0-logloss:0.01651	validation_0-auc:0.99981
# [193]	validation_0-logloss:0.01646	validation_0-auc:0.99981
# [194]	validation_0-logloss:0.01642	validation_0-auc:0.99981
# [195]	validation_0-logloss:0.01640	validation_0-auc:0.99981
# [196]	validation_0-logloss:0.01637	validation_0-auc:0.99981
# [197]	validation_0-logloss:0.01635	validation_0-auc:0.99981
# [198]	validation_0-logloss:0.01632	validation_0-auc:0.99981
# [199]	validation_0-logloss:0.01627	validation_0-auc:0.99981
# [200]	validation_0-logloss:0.01624	validation_0-auc:0.99981
# [201]	validation_0-logloss:0.01622	validation_0-auc:0.99981
# [202]	validation_0-logloss:0.01612	validation_0-auc:0.99982
# [203]	validation_0-logloss:0.01608	validation_0-auc:0.99982
# [204]	validation_0-logloss:0.01606	validation_0-auc:0.99982
# [205]	validation_0-logloss:0.01604	validation_0-auc:0.99982
# [206]	validation_0-logloss:0.01601	validation_0-auc:0.99982
# [207]	validation_0-logloss:0.01599	validation_0-auc:0.99982
# [208]	validation_0-logloss:0.01597	validation_0-auc:0.99982
# [209]	validation_0-logloss:0.01595	validation_0-auc:0.99982
# [210]	validation_0-logloss:0.01589	validation_0-auc:0.99982
# [211]	validation_0-logloss:0.01586	validation_0-auc:0.99982
# [212]	validation_0-logloss:0.01581	validation_0-auc:0.99982
# [213]	validation_0-logloss:0.01577	validation_0-auc:0.99982
# [214]	validation_0-logloss:0.01574	validation_0-auc:0.99983
# [215]	validation_0-logloss:0.01570	validation_0-auc:0.99983
# [216]	validation_0-logloss:0.01566	validation_0-auc:0.99983
# [217]	validation_0-logloss:0.01564	validation_0-auc:0.99983
# [218]	validation_0-logloss:0.01563	validation_0-auc:0.99983
# [219]	validation_0-logloss:0.01559	validation_0-auc:0.99983
# [220]	validation_0-logloss:0.01557	validation_0-auc:0.99983
# [221]	validation_0-logloss:0.01553	validation_0-auc:0.99983
# [222]	validation_0-logloss:0.01550	validation_0-auc:0.99983
# [223]	validation_0-logloss:0.01548	validation_0-auc:0.99983
# [224]	validation_0-logloss:0.01542	validation_0-auc:0.99983
# [225]	validation_0-logloss:0.01540	validation_0-auc:0.99983
# [226]	validation_0-logloss:0.01537	validation_0-auc:0.99983
# [227]	validation_0-logloss:0.01531	validation_0-auc:0.99984
# [228]	validation_0-logloss:0.01526	validation_0-auc:0.99984
# [229]	validation_0-logloss:0.01521	validation_0-auc:0.99984
# [230]	validation_0-logloss:0.01520	validation_0-auc:0.99984
# [231]	validation_0-logloss:0.01516	validation_0-auc:0.99984
# [232]	validation_0-logloss:0.01514	validation_0-auc:0.99984
# [233]	validation_0-logloss:0.01508	validation_0-auc:0.99984
# [234]	validation_0-logloss:0.01505	validation_0-auc:0.99984
# [235]	validation_0-logloss:0.01501	validation_0-auc:0.99984
# [236]	validation_0-logloss:0.01500	validation_0-auc:0.99984
# [237]	validation_0-logloss:0.01497	validation_0-auc:0.99984
# [238]	validation_0-logloss:0.01495	validation_0-auc:0.99984
# [239]	validation_0-logloss:0.01493	validation_0-auc:0.99984
# [240]	validation_0-logloss:0.01490	validation_0-auc:0.99984
# [241]	validation_0-logloss:0.01486	validation_0-auc:0.99985
# [242]	validation_0-logloss:0.01483	validation_0-auc:0.99985
# [243]	validation_0-logloss:0.01481	validation_0-auc:0.99985
# [244]	validation_0-logloss:0.01480	validation_0-auc:0.99985
# [245]	validation_0-logloss:0.01477	validation_0-auc:0.99985
# [246]	validation_0-logloss:0.01475	validation_0-auc:0.99985
# [247]	validation_0-logloss:0.01472	validation_0-auc:0.99985
# [248]	validation_0-logloss:0.01470	validation_0-auc:0.99985
# [249]	validation_0-logloss:0.01468	validation_0-auc:0.99985
# [250]	validation_0-logloss:0.01466	validation_0-auc:0.99985
# [251]	validation_0-logloss:0.01462	validation_0-auc:0.99985
# [252]	validation_0-logloss:0.01459	validation_0-auc:0.99985
# [253]	validation_0-logloss:0.01457	validation_0-auc:0.99985
# [254]	validation_0-logloss:0.01454	validation_0-auc:0.99985
# [255]	validation_0-logloss:0.01453	validation_0-auc:0.99985
# [256]	validation_0-logloss:0.01450	validation_0-auc:0.99985
# [257]	validation_0-logloss:0.01449	validation_0-auc:0.99985
# [258]	validation_0-logloss:0.01447	validation_0-auc:0.99985
# [259]	validation_0-logloss:0.01444	validation_0-auc:0.99985
# [260]	validation_0-logloss:0.01439	validation_0-auc:0.99986
# [261]	validation_0-logloss:0.01437	validation_0-auc:0.99986
# [262]	validation_0-logloss:0.01435	validation_0-auc:0.99986
# [263]	validation_0-logloss:0.01430	validation_0-auc:0.99986
# [264]	validation_0-logloss:0.01424	validation_0-auc:0.99986
# [265]	validation_0-logloss:0.01421	validation_0-auc:0.99986
# [266]	validation_0-logloss:0.01419	validation_0-auc:0.99986
# [267]	validation_0-logloss:0.01417	validation_0-auc:0.99986
# [268]	validation_0-logloss:0.01416	validation_0-auc:0.99986
# [269]	validation_0-logloss:0.01415	validation_0-auc:0.99986
# [270]	validation_0-logloss:0.01412	validation_0-auc:0.99986
# [271]	validation_0-logloss:0.01409	validation_0-auc:0.99986
# [272]	validation_0-logloss:0.01408	validation_0-auc:0.99986
# [273]	validation_0-logloss:0.01406	validation_0-auc:0.99986
# [274]	validation_0-logloss:0.01402	validation_0-auc:0.99986
# [275]	validation_0-logloss:0.01399	validation_0-auc:0.99986
# [276]	validation_0-logloss:0.01398	validation_0-auc:0.99986
# [277]	validation_0-logloss:0.01395	validation_0-auc:0.99986
# [278]	validation_0-logloss:0.01393	validation_0-auc:0.99986
# [279]	validation_0-logloss:0.01392	validation_0-auc:0.99986
# [280]	validation_0-logloss:0.01391	validation_0-auc:0.99986
# [281]	validation_0-logloss:0.01387	validation_0-auc:0.99986
# [282]	validation_0-logloss:0.01383	validation_0-auc:0.99987
# [283]	validation_0-logloss:0.01382	validation_0-auc:0.99987
# [284]	validation_0-logloss:0.01381	validation_0-auc:0.99987
# [285]	validation_0-logloss:0.01380	validation_0-auc:0.99987
# [286]	validation_0-logloss:0.01379	validation_0-auc:0.99987
# [287]	validation_0-logloss:0.01377	validation_0-auc:0.99987
# [288]	validation_0-logloss:0.01373	validation_0-auc:0.99987
# [289]	validation_0-logloss:0.01372	validation_0-auc:0.99987
# [290]	validation_0-logloss:0.01371	validation_0-auc:0.99987
# [291]	validation_0-logloss:0.01370	validation_0-auc:0.99987
# [292]	validation_0-logloss:0.01369	validation_0-auc:0.99987
# [293]	validation_0-logloss:0.01366	validation_0-auc:0.99987
# [294]	validation_0-logloss:0.01362	validation_0-auc:0.99987
# [295]	validation_0-logloss:0.01360	validation_0-auc:0.99987
# [296]	validation_0-logloss:0.01357	validation_0-auc:0.99987
# [297]	validation_0-logloss:0.01355	validation_0-auc:0.99987
# [298]	validation_0-logloss:0.01352	validation_0-auc:0.99987
# [299]	validation_0-logloss:0.01351	validation_0-auc:0.99987
# [300]	validation_0-logloss:0.01350	validation_0-auc:0.99987
# [301]	validation_0-logloss:0.01350	validation_0-auc:0.99987
# [302]	validation_0-logloss:0.01346	validation_0-auc:0.99987
# [303]	validation_0-logloss:0.01344	validation_0-auc:0.99987
# [304]	validation_0-logloss:0.01344	validation_0-auc:0.99987
# [305]	validation_0-logloss:0.01342	validation_0-auc:0.99987
# [306]	validation_0-logloss:0.01340	validation_0-auc:0.99987
# [307]	validation_0-logloss:0.01338	validation_0-auc:0.99987
# [308]	validation_0-logloss:0.01335	validation_0-auc:0.99988
# [309]	validation_0-logloss:0.01331	validation_0-auc:0.99988
# [310]	validation_0-logloss:0.01330	validation_0-auc:0.99988
# [311]	validation_0-logloss:0.01327	validation_0-auc:0.99988
# [312]	validation_0-logloss:0.01325	validation_0-auc:0.99988
# [313]	validation_0-logloss:0.01323	validation_0-auc:0.99988
# [314]	validation_0-logloss:0.01322	validation_0-auc:0.99988
# [315]	validation_0-logloss:0.01321	validation_0-auc:0.99988
# [316]	validation_0-logloss:0.01318	validation_0-auc:0.99988
# [317]	validation_0-logloss:0.01317	validation_0-auc:0.99988
# [318]	validation_0-logloss:0.01315	validation_0-auc:0.99988
# [319]	validation_0-logloss:0.01315	validation_0-auc:0.99988
# [320]	validation_0-logloss:0.01313	validation_0-auc:0.99988
# [321]	validation_0-logloss:0.01311	validation_0-auc:0.99988
# [322]	validation_0-logloss:0.01309	validation_0-auc:0.99988
# [323]	validation_0-logloss:0.01306	validation_0-auc:0.99988
# [324]	validation_0-logloss:0.01305	validation_0-auc:0.99988
# [325]	validation_0-logloss:0.01304	validation_0-auc:0.99988
# [326]	validation_0-logloss:0.01301	validation_0-auc:0.99988
# [327]	validation_0-logloss:0.01300	validation_0-auc:0.99988
# [328]	validation_0-logloss:0.01299	validation_0-auc:0.99988
# [329]	validation_0-logloss:0.01295	validation_0-auc:0.99988
# [330]	validation_0-logloss:0.01294	validation_0-auc:0.99988
# [331]	validation_0-logloss:0.01294	validation_0-auc:0.99988
# [332]	validation_0-logloss:0.01291	validation_0-auc:0.99988
# [333]	validation_0-logloss:0.01290	validation_0-auc:0.99988
# [334]	validation_0-logloss:0.01289	validation_0-auc:0.99988
# [335]	validation_0-logloss:0.01287	validation_0-auc:0.99988
# [336]	validation_0-logloss:0.01287	validation_0-auc:0.99988
# [337]	validation_0-logloss:0.01286	validation_0-auc:0.99988
# [338]	validation_0-logloss:0.01286	validation_0-auc:0.99988
# [339]	validation_0-logloss:0.01284	validation_0-auc:0.99988
# [340]	validation_0-logloss:0.01282	validation_0-auc:0.99989
# [341]	validation_0-logloss:0.01279	validation_0-auc:0.99989
# [342]	validation_0-logloss:0.01279	validation_0-auc:0.99989
# [343]	validation_0-logloss:0.01278	validation_0-auc:0.99989
# [344]	validation_0-logloss:0.01277	validation_0-auc:0.99989
# [345]	validation_0-logloss:0.01275	validation_0-auc:0.99989
# [346]	validation_0-logloss:0.01274	validation_0-auc:0.99989
# [347]	validation_0-logloss:0.01271	validation_0-auc:0.99989
# [348]	validation_0-logloss:0.01270	validation_0-auc:0.99989
# [349]	validation_0-logloss:0.01270	validation_0-auc:0.99989
# [350]	validation_0-logloss:0.01269	validation_0-auc:0.99989
# [351]	validation_0-logloss:0.01268	validation_0-auc:0.99989
# [352]	validation_0-logloss:0.01267	validation_0-auc:0.99989
# [353]	validation_0-logloss:0.01266	validation_0-auc:0.99989
# [354]	validation_0-logloss:0.01263	validation_0-auc:0.99989
# [355]	validation_0-logloss:0.01261	validation_0-auc:0.99989
# [356]	validation_0-logloss:0.01259	validation_0-auc:0.99989
# [357]	validation_0-logloss:0.01258	validation_0-auc:0.99989
# [358]	validation_0-logloss:0.01256	validation_0-auc:0.99989
# [359]	validation_0-logloss:0.01254	validation_0-auc:0.99989
# [360]	validation_0-logloss:0.01254	validation_0-auc:0.99989
# [361]	validation_0-logloss:0.01252	validation_0-auc:0.99989
# [362]	validation_0-logloss:0.01251	validation_0-auc:0.99989
# [363]	validation_0-logloss:0.01249	validation_0-auc:0.99989
# [364]	validation_0-logloss:0.01248	validation_0-auc:0.99989
# [365]	validation_0-logloss:0.01246	validation_0-auc:0.99989
# [366]	validation_0-logloss:0.01244	validation_0-auc:0.99989
# [367]	validation_0-logloss:0.01244	validation_0-auc:0.99989
# [368]	validation_0-logloss:0.01242	validation_0-auc:0.99989
# [369]	validation_0-logloss:0.01242	validation_0-auc:0.99989
# [370]	validation_0-logloss:0.01239	validation_0-auc:0.99989
# [371]	validation_0-logloss:0.01239	validation_0-auc:0.99989
# [372]	validation_0-logloss:0.01237	validation_0-auc:0.99989
# [373]	validation_0-logloss:0.01236	validation_0-auc:0.99989
# [374]	validation_0-logloss:0.01234	validation_0-auc:0.99989
# [375]	validation_0-logloss:0.01233	validation_0-auc:0.99989
# [376]	validation_0-logloss:0.01231	validation_0-auc:0.99989
# [377]	validation_0-logloss:0.01230	validation_0-auc:0.99989
# [378]	validation_0-logloss:0.01229	validation_0-auc:0.99989
# [379]	validation_0-logloss:0.01226	validation_0-auc:0.99989
# [380]	validation_0-logloss:0.01226	validation_0-auc:0.99989
# [381]	validation_0-logloss:0.01225	validation_0-auc:0.99989
# [382]	validation_0-logloss:0.01224	validation_0-auc:0.99989
# [383]	validation_0-logloss:0.01223	validation_0-auc:0.99989
# [384]	validation_0-logloss:0.01221	validation_0-auc:0.99989
# [385]	validation_0-logloss:0.01220	validation_0-auc:0.99990
# [386]	validation_0-logloss:0.01219	validation_0-auc:0.99990
# [387]	validation_0-logloss:0.01218	validation_0-auc:0.99990
# [388]	validation_0-logloss:0.01217	validation_0-auc:0.99990
# [389]	validation_0-logloss:0.01216	validation_0-auc:0.99990
# [390]	validation_0-logloss:0.01215	validation_0-auc:0.99990
# [391]	validation_0-logloss:0.01214	validation_0-auc:0.99990
# [392]	validation_0-logloss:0.01213	validation_0-auc:0.99990
# [393]	validation_0-logloss:0.01213	validation_0-auc:0.99990
# [394]	validation_0-logloss:0.01212	validation_0-auc:0.99990
# [395]	validation_0-logloss:0.01211	validation_0-auc:0.99990
# [396]	validation_0-logloss:0.01210	validation_0-auc:0.99990
# [397]	validation_0-logloss:0.01210	validation_0-auc:0.99990
# [398]	validation_0-logloss:0.01208	validation_0-auc:0.99990
# [399]	validation_0-logloss:0.01208	validation_0-auc:0.99990
# [400]	validation_0-logloss:0.01207	validation_0-auc:0.99990
# [401]	validation_0-logloss:0.01206	validation_0-auc:0.99990
# [402]	validation_0-logloss:0.01205	validation_0-auc:0.99990
# [403]	validation_0-logloss:0.01205	validation_0-auc:0.99990
# [404]	validation_0-logloss:0.01204	validation_0-auc:0.99990
# [405]	validation_0-logloss:0.01203	validation_0-auc:0.99990
# [406]	validation_0-logloss:0.01201	validation_0-auc:0.99990
# [407]	validation_0-logloss:0.01200	validation_0-auc:0.99990
# [408]	validation_0-logloss:0.01199	validation_0-auc:0.99990
# [409]	validation_0-logloss:0.01198	validation_0-auc:0.99990
# [410]	validation_0-logloss:0.01197	validation_0-auc:0.99990
# [411]	validation_0-logloss:0.01196	validation_0-auc:0.99990
# [412]	validation_0-logloss:0.01195	validation_0-auc:0.99990
# [413]	validation_0-logloss:0.01194	validation_0-auc:0.99990
# [414]	validation_0-logloss:0.01192	validation_0-auc:0.99990
# [415]	validation_0-logloss:0.01191	validation_0-auc:0.99990
# [416]	validation_0-logloss:0.01189	validation_0-auc:0.99990
# [417]	validation_0-logloss:0.01188	validation_0-auc:0.99990
# [418]	validation_0-logloss:0.01187	validation_0-auc:0.99990
# [419]	validation_0-logloss:0.01186	validation_0-auc:0.99990
# [420]	validation_0-logloss:0.01184	validation_0-auc:0.99990
# [421]	validation_0-logloss:0.01183	validation_0-auc:0.99990
# [422]	validation_0-logloss:0.01182	validation_0-auc:0.99990
# [423]	validation_0-logloss:0.01180	validation_0-auc:0.99990
# [424]	validation_0-logloss:0.01179	validation_0-auc:0.99990
# [425]	validation_0-logloss:0.01178	validation_0-auc:0.99990
# [426]	validation_0-logloss:0.01178	validation_0-auc:0.99990
# [427]	validation_0-logloss:0.01177	validation_0-auc:0.99990
# [428]	validation_0-logloss:0.01176	validation_0-auc:0.99990
# [429]	validation_0-logloss:0.01175	validation_0-auc:0.99990
# [430]	validation_0-logloss:0.01174	validation_0-auc:0.99990
# [431]	validation_0-logloss:0.01173	validation_0-auc:0.99990
# [432]	validation_0-logloss:0.01171	validation_0-auc:0.99990
# [433]	validation_0-logloss:0.01170	validation_0-auc:0.99990
# [434]	validation_0-logloss:0.01169	validation_0-auc:0.99990
# [435]	validation_0-logloss:0.01169	validation_0-auc:0.99990
# [436]	validation_0-logloss:0.01168	validation_0-auc:0.99990
# [437]	validation_0-logloss:0.01167	validation_0-auc:0.99990
# [438]	validation_0-logloss:0.01166	validation_0-auc:0.99990
# [439]	validation_0-logloss:0.01165	validation_0-auc:0.99990
# [440]	validation_0-logloss:0.01165	validation_0-auc:0.99990
# [441]	validation_0-logloss:0.01164	validation_0-auc:0.99990
# [442]	validation_0-logloss:0.01163	validation_0-auc:0.99990
# [443]	validation_0-logloss:0.01163	validation_0-auc:0.99990
# [444]	validation_0-logloss:0.01162	validation_0-auc:0.99990
# [445]	validation_0-logloss:0.01162	validation_0-auc:0.99990
# [446]	validation_0-logloss:0.01161	validation_0-auc:0.99990
# [447]	validation_0-logloss:0.01160	validation_0-auc:0.99990
# [448]	validation_0-logloss:0.01159	validation_0-auc:0.99990
# [449]	validation_0-logloss:0.01158	validation_0-auc:0.99990
# [450]	validation_0-logloss:0.01158	validation_0-auc:0.99990
# [451]	validation_0-logloss:0.01157	validation_0-auc:0.99990
# [452]	validation_0-logloss:0.01156	validation_0-auc:0.99990
# [453]	validation_0-logloss:0.01156	validation_0-auc:0.99990
# [454]	validation_0-logloss:0.01155	validation_0-auc:0.99990
# [455]	validation_0-logloss:0.01155	validation_0-auc:0.99990
# [456]	validation_0-logloss:0.01153	validation_0-auc:0.99991
# [457]	validation_0-logloss:0.01152	validation_0-auc:0.99991
# [458]	validation_0-logloss:0.01152	validation_0-auc:0.99991
# [459]	validation_0-logloss:0.01151	validation_0-auc:0.99991
# [460]	validation_0-logloss:0.01150	validation_0-auc:0.99991
# [461]	validation_0-logloss:0.01150	validation_0-auc:0.99991
# [462]	validation_0-logloss:0.01148	validation_0-auc:0.99991
# [463]	validation_0-logloss:0.01146	validation_0-auc:0.99991
# [464]	validation_0-logloss:0.01146	validation_0-auc:0.99991
# [465]	validation_0-logloss:0.01145	validation_0-auc:0.99991
# [466]	validation_0-logloss:0.01144	validation_0-auc:0.99991
# [467]	validation_0-logloss:0.01143	validation_0-auc:0.99991
# [468]	validation_0-logloss:0.01142	validation_0-auc:0.99991
# [469]	validation_0-logloss:0.01142	validation_0-auc:0.99991
# [470]	validation_0-logloss:0.01140	validation_0-auc:0.99991
# [471]	validation_0-logloss:0.01140	validation_0-auc:0.99991
# [472]	validation_0-logloss:0.01139	validation_0-auc:0.99991
# [473]	validation_0-logloss:0.01139	validation_0-auc:0.99991
# [474]	validation_0-logloss:0.01138	validation_0-auc:0.99991
# [475]	validation_0-logloss:0.01137	validation_0-auc:0.99991
# [476]	validation_0-logloss:0.01137	validation_0-auc:0.99991
# [477]	validation_0-logloss:0.01136	validation_0-auc:0.99991
# [478]	validation_0-logloss:0.01135	validation_0-auc:0.99991
# [479]	validation_0-logloss:0.01134	validation_0-auc:0.99991
# [480]	validation_0-logloss:0.01134	validation_0-auc:0.99991
# [481]	validation_0-logloss:0.01132	validation_0-auc:0.99991
# [482]	validation_0-logloss:0.01132	validation_0-auc:0.99991
# [483]	validation_0-logloss:0.01130	validation_0-auc:0.99991
# [484]	validation_0-logloss:0.01129	validation_0-auc:0.99991
# [485]	validation_0-logloss:0.01128	validation_0-auc:0.99991
# [486]	validation_0-logloss:0.01128	validation_0-auc:0.99991
# [487]	validation_0-logloss:0.01127	validation_0-auc:0.99991
# [488]	validation_0-logloss:0.01126	validation_0-auc:0.99991
# [489]	validation_0-logloss:0.01126	validation_0-auc:0.99991
# [490]	validation_0-logloss:0.01125	validation_0-auc:0.99991
# [491]	validation_0-logloss:0.01124	validation_0-auc:0.99991
# [492]	validation_0-logloss:0.01122	validation_0-auc:0.99991
# [493]	validation_0-logloss:0.01121	validation_0-auc:0.99991
# [494]	validation_0-logloss:0.01121	validation_0-auc:0.99991
# [495]	validation_0-logloss:0.01120	validation_0-auc:0.99991
# [496]	validation_0-logloss:0.01120	validation_0-auc:0.99991
# [497]	validation_0-logloss:0.01120	validation_0-auc:0.99991
# [498]	validation_0-logloss:0.01119	validation_0-auc:0.99991
# [499]	validation_0-logloss:0.01118	validation_0-auc:0.99991
# [500]	validation_0-logloss:0.01117	validation_0-auc:0.99991
# [501]	validation_0-logloss:0.01116	validation_0-auc:0.99991
# [502]	validation_0-logloss:0.01115	validation_0-auc:0.99991
# [503]	validation_0-logloss:0.01115	validation_0-auc:0.99991
# [504]	validation_0-logloss:0.01114	validation_0-auc:0.99991
# [505]	validation_0-logloss:0.01114	validation_0-auc:0.99991
# [506]	validation_0-logloss:0.01113	validation_0-auc:0.99991
# [507]	validation_0-logloss:0.01113	validation_0-auc:0.99991
# [508]	validation_0-logloss:0.01113	validation_0-auc:0.99991
# [509]	validation_0-logloss:0.01112	validation_0-auc:0.99991
# [510]	validation_0-logloss:0.01112	validation_0-auc:0.99991
# [511]	validation_0-logloss:0.01111	validation_0-auc:0.99991
# [512]	validation_0-logloss:0.01110	validation_0-auc:0.99991
# [513]	validation_0-logloss:0.01109	validation_0-auc:0.99991
# [514]	validation_0-logloss:0.01107	validation_0-auc:0.99991
# [515]	validation_0-logloss:0.01107	validation_0-auc:0.99991
# [516]	validation_0-logloss:0.01106	validation_0-auc:0.99991
# [517]	validation_0-logloss:0.01104	validation_0-auc:0.99991
# [518]	validation_0-logloss:0.01104	validation_0-auc:0.99991
# [519]	validation_0-logloss:0.01103	validation_0-auc:0.99991
# [520]	validation_0-logloss:0.01103	validation_0-auc:0.99991
# [521]	validation_0-logloss:0.01103	validation_0-auc:0.99991
# [522]	validation_0-logloss:0.01102	validation_0-auc:0.99991
# [523]	validation_0-logloss:0.01102	validation_0-auc:0.99991
# [524]	validation_0-logloss:0.01101	validation_0-auc:0.99991
# [525]	validation_0-logloss:0.01100	validation_0-auc:0.99991
# [526]	validation_0-logloss:0.01100	validation_0-auc:0.99991
# [527]	validation_0-logloss:0.01100	validation_0-auc:0.99991
# [528]	validation_0-logloss:0.01098	validation_0-auc:0.99991
# [529]	validation_0-logloss:0.01097	validation_0-auc:0.99991
# [530]	validation_0-logloss:0.01097	validation_0-auc:0.99991
# [531]	validation_0-logloss:0.01096	validation_0-auc:0.99991
# [532]	validation_0-logloss:0.01095	validation_0-auc:0.99991
# [533]	validation_0-logloss:0.01094	validation_0-auc:0.99991
# [534]	validation_0-logloss:0.01094	validation_0-auc:0.99991
# [535]	validation_0-logloss:0.01093	validation_0-auc:0.99991
# [536]	validation_0-logloss:0.01093	validation_0-auc:0.99991
# [537]	validation_0-logloss:0.01092	validation_0-auc:0.99991
# [538]	validation_0-logloss:0.01091	validation_0-auc:0.99991
# [539]	validation_0-logloss:0.01090	validation_0-auc:0.99991
# [540]	validation_0-logloss:0.01089	validation_0-auc:0.99991
# [541]	validation_0-logloss:0.01088	validation_0-auc:0.99991
# [542]	validation_0-logloss:0.01087	validation_0-auc:0.99991
# [543]	validation_0-logloss:0.01087	validation_0-auc:0.99992
# [544]	validation_0-logloss:0.01085	validation_0-auc:0.99992
# [545]	validation_0-logloss:0.01085	validation_0-auc:0.99992
# [546]	validation_0-logloss:0.01085	validation_0-auc:0.99992
# [547]	validation_0-logloss:0.01084	validation_0-auc:0.99992
# [548]	validation_0-logloss:0.01084	validation_0-auc:0.99992
# [549]	validation_0-logloss:0.01084	validation_0-auc:0.99992
# [550]	validation_0-logloss:0.01083	validation_0-auc:0.99992
# [551]	validation_0-logloss:0.01083	validation_0-auc:0.99992
# [552]	validation_0-logloss:0.01083	validation_0-auc:0.99992
# [553]	validation_0-logloss:0.01082	validation_0-auc:0.99992
# [554]	validation_0-logloss:0.01081	validation_0-auc:0.99992
# [555]	validation_0-logloss:0.01081	validation_0-auc:0.99992
# [556]	validation_0-logloss:0.01080	validation_0-auc:0.99992
# [557]	validation_0-logloss:0.01080	validation_0-auc:0.99992
# [558]	validation_0-logloss:0.01079	validation_0-auc:0.99992
# [559]	validation_0-logloss:0.01079	validation_0-auc:0.99992
# [560]	validation_0-logloss:0.01078	validation_0-auc:0.99992
# [561]	validation_0-logloss:0.01077	validation_0-auc:0.99992
# [562]	validation_0-logloss:0.01076	validation_0-auc:0.99992
# [563]	validation_0-logloss:0.01075	validation_0-auc:0.99992
# [564]	validation_0-logloss:0.01075	validation_0-auc:0.99992
# [565]	validation_0-logloss:0.01075	validation_0-auc:0.99992
# [566]	validation_0-logloss:0.01074	validation_0-auc:0.99992
# [567]	validation_0-logloss:0.01074	validation_0-auc:0.99992
# [568]	validation_0-logloss:0.01074	validation_0-auc:0.99992
# [569]	validation_0-logloss:0.01072	validation_0-auc:0.99992
# [570]	validation_0-logloss:0.01072	validation_0-auc:0.99992
# [571]	validation_0-logloss:0.01071	validation_0-auc:0.99992
# [572]	validation_0-logloss:0.01071	validation_0-auc:0.99992
# [573]	validation_0-logloss:0.01070	validation_0-auc:0.99992
# [574]	validation_0-logloss:0.01070	validation_0-auc:0.99992
# [575]	validation_0-logloss:0.01070	validation_0-auc:0.99992
# [576]	validation_0-logloss:0.01068	validation_0-auc:0.99992
# [577]	validation_0-logloss:0.01068	validation_0-auc:0.99992
# [578]	validation_0-logloss:0.01067	validation_0-auc:0.99992
# [579]	validation_0-logloss:0.01066	validation_0-auc:0.99992
# [580]	validation_0-logloss:0.01066	validation_0-auc:0.99992
# [581]	validation_0-logloss:0.01065	validation_0-auc:0.99992
# [582]	validation_0-logloss:0.01065	validation_0-auc:0.99992
# [583]	validation_0-logloss:0.01064	validation_0-auc:0.99992
# [584]	validation_0-logloss:0.01064	validation_0-auc:0.99992
# [585]	validation_0-logloss:0.01063	validation_0-auc:0.99992
# [586]	validation_0-logloss:0.01063	validation_0-auc:0.99992
# [587]	validation_0-logloss:0.01063	validation_0-auc:0.99992
# [588]	validation_0-logloss:0.01062	validation_0-auc:0.99992
# [589]	validation_0-logloss:0.01062	validation_0-auc:0.99992
# [590]	validation_0-logloss:0.01062	validation_0-auc:0.99992
# [591]	validation_0-logloss:0.01061	validation_0-auc:0.99992
# [592]	validation_0-logloss:0.01061	validation_0-auc:0.99992
# [593]	validation_0-logloss:0.01061	validation_0-auc:0.99992
# [594]	validation_0-logloss:0.01060	validation_0-auc:0.99992
# [595]	validation_0-logloss:0.01060	validation_0-auc:0.99992
# [596]	validation_0-logloss:0.01060	validation_0-auc:0.99992
# [597]	validation_0-logloss:0.01060	validation_0-auc:0.99992
# [598]	validation_0-logloss:0.01060	validation_0-auc:0.99992
# [599]	validation_0-logloss:0.01059	validation_0-auc:0.99992
# [600]	validation_0-logloss:0.01057	validation_0-auc:0.99992
# [601]	validation_0-logloss:0.01057	validation_0-auc:0.99992
# [602]	validation_0-logloss:0.01057	validation_0-auc:0.99992
# [603]	validation_0-logloss:0.01056	validation_0-auc:0.99992
# [604]	validation_0-logloss:0.01056	validation_0-auc:0.99992
# [605]	validation_0-logloss:0.01055	validation_0-auc:0.99992
# [606]	validation_0-logloss:0.01054	validation_0-auc:0.99992
# [607]	validation_0-logloss:0.01054	validation_0-auc:0.99992
# [608]	validation_0-logloss:0.01053	validation_0-auc:0.99992
# [609]	validation_0-logloss:0.01053	validation_0-auc:0.99992
# [610]	validation_0-logloss:0.01052	validation_0-auc:0.99992
# [611]	validation_0-logloss:0.01052	validation_0-auc:0.99992
# [612]	validation_0-logloss:0.01052	validation_0-auc:0.99992
# [613]	validation_0-logloss:0.01051	validation_0-auc:0.99992
# [614]	validation_0-logloss:0.01050	validation_0-auc:0.99992
# [615]	validation_0-logloss:0.01049	validation_0-auc:0.99992
# [616]	validation_0-logloss:0.01049	validation_0-auc:0.99992
# [617]	validation_0-logloss:0.01048	validation_0-auc:0.99992
# [618]	validation_0-logloss:0.01048	validation_0-auc:0.99992
# [619]	validation_0-logloss:0.01048	validation_0-auc:0.99992
# [620]	validation_0-logloss:0.01048	validation_0-auc:0.99992
# [621]	validation_0-logloss:0.01047	validation_0-auc:0.99992
# [622]	validation_0-logloss:0.01046	validation_0-auc:0.99992
# [623]	validation_0-logloss:0.01045	validation_0-auc:0.99992
# [624]	validation_0-logloss:0.01045	validation_0-auc:0.99992
# [625]	validation_0-logloss:0.01044	validation_0-auc:0.99992
# [626]	validation_0-logloss:0.01044	validation_0-auc:0.99992
# [627]	validation_0-logloss:0.01043	validation_0-auc:0.99992
# [628]	validation_0-logloss:0.01042	validation_0-auc:0.99992
# [629]	validation_0-logloss:0.01042	validation_0-auc:0.99992
# [630]	validation_0-logloss:0.01041	validation_0-auc:0.99992
# [631]	validation_0-logloss:0.01040	validation_0-auc:0.99992
# [632]	validation_0-logloss:0.01039	validation_0-auc:0.99992
# [633]	validation_0-logloss:0.01038	validation_0-auc:0.99992
# [634]	validation_0-logloss:0.01038	validation_0-auc:0.99992
# [635]	validation_0-logloss:0.01037	validation_0-auc:0.99992
# [636]	validation_0-logloss:0.01037	validation_0-auc:0.99992
# [637]	validation_0-logloss:0.01037	validation_0-auc:0.99992
# [638]	validation_0-logloss:0.01037	validation_0-auc:0.99992
# [639]	validation_0-logloss:0.01037	validation_0-auc:0.99992
# [640]	validation_0-logloss:0.01036	validation_0-auc:0.99992
# [641]	validation_0-logloss:0.01036	validation_0-auc:0.99992
# [642]	validation_0-logloss:0.01036	validation_0-auc:0.99992
# [643]	validation_0-logloss:0.01035	validation_0-auc:0.99992
# [644]	validation_0-logloss:0.01034	validation_0-auc:0.99992
# [645]	validation_0-logloss:0.01034	validation_0-auc:0.99992
# [646]	validation_0-logloss:0.01034	validation_0-auc:0.99992
# [647]	validation_0-logloss:0.01034	validation_0-auc:0.99992
# [648]	validation_0-logloss:0.01033	validation_0-auc:0.99992
# [649]	validation_0-logloss:0.01033	validation_0-auc:0.99992
# [650]	validation_0-logloss:0.01033	validation_0-auc:0.99992
# [651]	validation_0-logloss:0.01033	validation_0-auc:0.99992
# [652]	validation_0-logloss:0.01033	validation_0-auc:0.99992
# [653]	validation_0-logloss:0.01032	validation_0-auc:0.99992
# [654]	validation_0-logloss:0.01032	validation_0-auc:0.99992
# [655]	validation_0-logloss:0.01032	validation_0-auc:0.99992
# [656]	validation_0-logloss:0.01031	validation_0-auc:0.99992
# [657]	validation_0-logloss:0.01031	validation_0-auc:0.99992
# [658]	validation_0-logloss:0.01030	validation_0-auc:0.99992
# [659]	validation_0-logloss:0.01030	validation_0-auc:0.99992
# [660]	validation_0-logloss:0.01029	validation_0-auc:0.99992
# [661]	validation_0-logloss:0.01029	validation_0-auc:0.99992
# [662]	validation_0-logloss:0.01029	validation_0-auc:0.99992
# [663]	validation_0-logloss:0.01028	validation_0-auc:0.99992
# [664]	validation_0-logloss:0.01028	validation_0-auc:0.99992
# [665]	validation_0-logloss:0.01028	validation_0-auc:0.99992
# [666]	validation_0-logloss:0.01027	validation_0-auc:0.99992
# [667]	validation_0-logloss:0.01026	validation_0-auc:0.99992
# [668]	validation_0-logloss:0.01026	validation_0-auc:0.99992
# [669]	validation_0-logloss:0.01025	validation_0-auc:0.99992
# [670]	validation_0-logloss:0.01025	validation_0-auc:0.99992
# [671]	validation_0-logloss:0.01025	validation_0-auc:0.99992
# [672]	validation_0-logloss:0.01025	validation_0-auc:0.99992
# [673]	validation_0-logloss:0.01024	validation_0-auc:0.99992
# [674]	validation_0-logloss:0.01024	validation_0-auc:0.99992
# [675]	validation_0-logloss:0.01023	validation_0-auc:0.99992
# [676]	validation_0-logloss:0.01023	validation_0-auc:0.99992
# [677]	validation_0-logloss:0.01023	validation_0-auc:0.99992
# [678]	validation_0-logloss:0.01023	validation_0-auc:0.99992
# [679]	validation_0-logloss:0.01022	validation_0-auc:0.99992
# [680]	validation_0-logloss:0.01021	validation_0-auc:0.99992
# [681]	validation_0-logloss:0.01021	validation_0-auc:0.99992
# [682]	validation_0-logloss:0.01020	validation_0-auc:0.99992
# [683]	validation_0-logloss:0.01019	validation_0-auc:0.99992
# [684]	validation_0-logloss:0.01019	validation_0-auc:0.99992
# [685]	validation_0-logloss:0.01019	validation_0-auc:0.99992
# [686]	validation_0-logloss:0.01019	validation_0-auc:0.99992
# [687]	validation_0-logloss:0.01019	validation_0-auc:0.99992
# [688]	validation_0-logloss:0.01019	validation_0-auc:0.99992
# [689]	validation_0-logloss:0.01019	validation_0-auc:0.99992
# [690]	validation_0-logloss:0.01018	validation_0-auc:0.99992
# [691]	validation_0-logloss:0.01017	validation_0-auc:0.99992
# [692]	validation_0-logloss:0.01017	validation_0-auc:0.99992
# [693]	validation_0-logloss:0.01016	validation_0-auc:0.99992
# [694]	validation_0-logloss:0.01015	validation_0-auc:0.99992
# [695]	validation_0-logloss:0.01015	validation_0-auc:0.99992
# [696]	validation_0-logloss:0.01015	validation_0-auc:0.99992
# [697]	validation_0-logloss:0.01015	validation_0-auc:0.99992
# [698]	validation_0-logloss:0.01014	validation_0-auc:0.99992
# [699]	validation_0-logloss:0.01014	validation_0-auc:0.99992
# [700]	validation_0-logloss:0.01014	validation_0-auc:0.99992
# [701]	validation_0-logloss:0.01013	validation_0-auc:0.99992
# [702]	validation_0-logloss:0.01012	validation_0-auc:0.99993
# [703]	validation_0-logloss:0.01012	validation_0-auc:0.99993
# [704]	validation_0-logloss:0.01012	validation_0-auc:0.99993
# [705]	validation_0-logloss:0.01011	validation_0-auc:0.99993
# [706]	validation_0-logloss:0.01011	validation_0-auc:0.99993
# [707]	validation_0-logloss:0.01011	validation_0-auc:0.99993
# [708]	validation_0-logloss:0.01011	validation_0-auc:0.99993
# [709]	validation_0-logloss:0.01011	validation_0-auc:0.99993
# [710]	validation_0-logloss:0.01010	validation_0-auc:0.99993
# [711]	validation_0-logloss:0.01010	validation_0-auc:0.99993
# [712]	validation_0-logloss:0.01010	validation_0-auc:0.99993
# [713]	validation_0-logloss:0.01009	validation_0-auc:0.99993
# [714]	validation_0-logloss:0.01009	validation_0-auc:0.99993
# [715]	validation_0-logloss:0.01008	validation_0-auc:0.99993
# [716]	validation_0-logloss:0.01008	validation_0-auc:0.99993
# [717]	validation_0-logloss:0.01007	validation_0-auc:0.99993
# [718]	validation_0-logloss:0.01007	validation_0-auc:0.99993
# [719]	validation_0-logloss:0.01007	validation_0-auc:0.99993
# [720]	validation_0-logloss:0.01006	validation_0-auc:0.99993
# [721]	validation_0-logloss:0.01006	validation_0-auc:0.99993
# [722]	validation_0-logloss:0.01006	validation_0-auc:0.99993
# [723]	validation_0-logloss:0.01006	validation_0-auc:0.99993
# [724]	validation_0-logloss:0.01005	validation_0-auc:0.99993
# [725]	validation_0-logloss:0.01004	validation_0-auc:0.99993
# [726]	validation_0-logloss:0.01003	validation_0-auc:0.99993
# [727]	validation_0-logloss:0.01002	validation_0-auc:0.99993
# [728]	validation_0-logloss:0.01002	validation_0-auc:0.99993
# [729]	validation_0-logloss:0.01001	validation_0-auc:0.99993
# [730]	validation_0-logloss:0.01001	validation_0-auc:0.99993
# [731]	validation_0-logloss:0.01001	validation_0-auc:0.99993
# [732]	validation_0-logloss:0.01001	validation_0-auc:0.99993
# [733]	validation_0-logloss:0.01000	validation_0-auc:0.99993
# [734]	validation_0-logloss:0.00999	validation_0-auc:0.99993
# [735]	validation_0-logloss:0.00999	validation_0-auc:0.99993
# [736]	validation_0-logloss:0.00999	validation_0-auc:0.99993
# [737]	validation_0-logloss:0.00998	validation_0-auc:0.99993
# [738]	validation_0-logloss:0.00998	validation_0-auc:0.99993
# [739]	validation_0-logloss:0.00998	validation_0-auc:0.99993
# [740]	validation_0-logloss:0.00998	validation_0-auc:0.99993
# [741]	validation_0-logloss:0.00998	validation_0-auc:0.99993
# [742]	validation_0-logloss:0.00997	validation_0-auc:0.99993
# [743]	validation_0-logloss:0.00997	validation_0-auc:0.99993
# [744]	validation_0-logloss:0.00996	validation_0-auc:0.99993
# [745]	validation_0-logloss:0.00996	validation_0-auc:0.99993
# [746]	validation_0-logloss:0.00996	validation_0-auc:0.99993
# [747]	validation_0-logloss:0.00995	validation_0-auc:0.99993
# [748]	validation_0-logloss:0.00995	validation_0-auc:0.99993
# [749]	validation_0-logloss:0.00995	validation_0-auc:0.99993
# [750]	validation_0-logloss:0.00995	validation_0-auc:0.99993
# [751]	validation_0-logloss:0.00995	validation_0-auc:0.99993
# [752]	validation_0-logloss:0.00994	validation_0-auc:0.99993
# [753]	validation_0-logloss:0.00994	validation_0-auc:0.99993
# [754]	validation_0-logloss:0.00993	validation_0-auc:0.99993
# [755]	validation_0-logloss:0.00993	validation_0-auc:0.99993
# [756]	validation_0-logloss:0.00992	validation_0-auc:0.99993
# [757]	validation_0-logloss:0.00992	validation_0-auc:0.99993
# [758]	validation_0-logloss:0.00992	validation_0-auc:0.99993
# [759]	validation_0-logloss:0.00992	validation_0-auc:0.99993
# [760]	validation_0-logloss:0.00991	validation_0-auc:0.99993
# [761]	validation_0-logloss:0.00991	validation_0-auc:0.99993
# [762]	validation_0-logloss:0.00991	validation_0-auc:0.99993
# [763]	validation_0-logloss:0.00990	validation_0-auc:0.99993
# [764]	validation_0-logloss:0.00990	validation_0-auc:0.99993
# [765]	validation_0-logloss:0.00990	validation_0-auc:0.99993
# [766]	validation_0-logloss:0.00989	validation_0-auc:0.99993
# [767]	validation_0-logloss:0.00989	validation_0-auc:0.99993
# [768]	validation_0-logloss:0.00989	validation_0-auc:0.99993
# [769]	validation_0-logloss:0.00989	validation_0-auc:0.99993
# [770]	validation_0-logloss:0.00988	validation_0-auc:0.99993
# [771]	validation_0-logloss:0.00988	validation_0-auc:0.99993
# [772]	validation_0-logloss:0.00988	validation_0-auc:0.99993
# [773]	validation_0-logloss:0.00987	validation_0-auc:0.99993
# [774]	validation_0-logloss:0.00987	validation_0-auc:0.99993
# [775]	validation_0-logloss:0.00987	validation_0-auc:0.99993
# [776]	validation_0-logloss:0.00987	validation_0-auc:0.99993
# [777]	validation_0-logloss:0.00987	validation_0-auc:0.99993
# [778]	validation_0-logloss:0.00987	validation_0-auc:0.99993
# [779]	validation_0-logloss:0.00986	validation_0-auc:0.99993
# [780]	validation_0-logloss:0.00986	validation_0-auc:0.99993
# [781]	validation_0-logloss:0.00986	validation_0-auc:0.99993
# [782]	validation_0-logloss:0.00986	validation_0-auc:0.99993
# [783]	validation_0-logloss:0.00985	validation_0-auc:0.99993
# [784]	validation_0-logloss:0.00985	validation_0-auc:0.99993
# [785]	validation_0-logloss:0.00985	validation_0-auc:0.99993
# [786]	validation_0-logloss:0.00984	validation_0-auc:0.99993
# [787]	validation_0-logloss:0.00984	validation_0-auc:0.99993
# [788]	validation_0-logloss:0.00984	validation_0-auc:0.99993
# [789]	validation_0-logloss:0.00984	validation_0-auc:0.99993
# [790]	validation_0-logloss:0.00984	validation_0-auc:0.99993
# [791]	validation_0-logloss:0.00983	validation_0-auc:0.99993
# [792]	validation_0-logloss:0.00982	validation_0-auc:0.99993
# [793]	validation_0-logloss:0.00982	validation_0-auc:0.99993
# [794]	validation_0-logloss:0.00982	validation_0-auc:0.99993
# [795]	validation_0-logloss:0.00982	validation_0-auc:0.99993
# [796]	validation_0-logloss:0.00981	validation_0-auc:0.99993
# [797]	validation_0-logloss:0.00981	validation_0-auc:0.99993
# [798]	validation_0-logloss:0.00981	validation_0-auc:0.99993
# [799]	validation_0-logloss:0.00981	validation_0-auc:0.99993
# [800]	validation_0-logloss:0.00981	validation_0-auc:0.99993
# ...
# [2265]	validation_0-logloss:0.00838	validation_0-auc:0.99995
# [2266]	validation_0-logloss:0.00838	validation_0-auc:0.99995
# [2267]	validation_0-logloss:0.00838	validation_0-auc:0.99995
# [2268]	validation_0-logloss:0.00838	validation_0-auc:0.99995
# [2269]	validation_0-logloss:0.00838	validation_0-auc:0.99995
# [2270]	validation_0-logloss:0.00838	validation_0-auc:0.99995
# [2271]	validation_0-logloss:0.00838	validation_0-auc:0.99995
# [2272]	validation_0-logloss:0.00838	validation_0-auc:0.99995
# [2273]	validation_0-logloss:0.00838	validation_0-auc:0.99995
# [2274]	validation_0-logloss:0.00838	validation_0-auc:0.99995
# [2275]	validation_0-logloss:0.00838	validation_0-auc:0.99995
# [2276]	validation_0-logloss:0.00838	validation_0-auc:0.99995
# [2277]	validation_0-logloss:0.00838	validation_0-auc:0.99995
# [2278]	validation_0-logloss:0.00838	validation_0-auc:0.99995
# [2279]	validation_0-logloss:0.00838	validation_0-auc:0.99995
# [2280]	validation_0-logloss:0.00838	validation_0-auc:0.99995
# [2281]	validation_0-logloss:0.00838	validation_0-auc:0.99995
# [2282]	validation_0-logloss:0.00838	validation_0-auc:0.99995
# [2283]	validation_0-logloss:0.00838	validation_0-auc:0.99995
# [2284]	validation_0-logloss:0.00838	validation_0-auc:0.99995
# [2285]	validation_0-logloss:0.00838	validation_0-auc:0.99995
# [2286]	validation_0-logloss:0.00838	validation_0-auc:0.99995
# [2287]	validation_0-logloss:0.00837	validation_0-auc:0.99995
# [2288]	validation_0-logloss:0.00838	validation_0-auc:0.99995
# [2289]	validation_0-logloss:0.00837	validation_0-auc:0.99995
# [2290]	validation_0-logloss:0.00837	validation_0-auc:0.99995
# [2291]	validation_0-logloss:0.00838	validation_0-auc:0.99995
# [2292]	validation_0-logloss:0.00838	validation_0-auc:0.99995
# [2293]	validation_0-logloss:0.00838	validation_0-auc:0.99995
# [2294]	validation_0-logloss:0.00838	validation_0-auc:0.99995
# [2295]	validation_0-logloss:0.00838	validation_0-auc:0.99995
# [2296]	validation_0-logloss:0.00837	validation_0-auc:0.99995
# [2297]	validation_0-logloss:0.00837	validation_0-auc:0.99995
# [2298]	validation_0-logloss:0.00837	validation_0-auc:0.99995
# [2299]	validation_0-logloss:0.00837	validation_0-auc:0.99995
# [2300]	validation_0-logloss:0.00837	validation_0-auc:0.99995
# [2301]	validation_0-logloss:0.00837	validation_0-auc:0.99995
# [2302]	validation_0-logloss:0.00837	validation_0-auc:0.99995
# [2303]	validation_0-logloss:0.00837	validation_0-auc:0.99995
# [2304]	validation_0-logloss:0.00837	validation_0-auc:0.99995
# [2305]	validation_0-logloss:0.00837	validation_0-auc:0.99995
# [2306]	validation_0-logloss:0.00837	validation_0-auc:0.99995
# [2307]	validation_0-logloss:0.00837	validation_0-auc:0.99995
# [2308]	validation_0-logloss:0.00837	validation_0-auc:0.99995
# [2309]	validation_0-logloss:0.00837	validation_0-auc:0.99995
# [2310]	validation_0-logloss:0.00837	validation_0-auc:0.99995
# [2311]	validation_0-logloss:0.00837	validation_0-auc:0.99995
# [2312]	validation_0-logloss:0.00837	validation_0-auc:0.99995
# [2313]	validation_0-logloss:0.00837	validation_0-auc:0.99995
# [2314]	validation_0-logloss:0.00837	validation_0-auc:0.99995
# [2315]	validation_0-logloss:0.00837	validation_0-auc:0.99995
# [2316]	validation_0-logloss:0.00837	validation_0-auc:0.99995
# [2317]	validation_0-logloss:0.00837	validation_0-auc:0.99995
# [2318]	validation_0-logloss:0.00837	validation_0-auc:0.99995
# [2319]	validation_0-logloss:0.00837	validation_0-auc:0.99995
# [2320]	validation_0-logloss:0.00837	validation_0-auc:0.99995
# [2321]	validation_0-logloss:0.00837	validation_0-auc:0.99995
# [2322]	validation_0-logloss:0.00837	validation_0-auc:0.99995
# [2323]	validation_0-logloss:0.00837	validation_0-auc:0.99995
# [2324]	validation_0-logloss:0.00837	validation_0-auc:0.99995
# [2325]	validation_0-logloss:0.00837	validation_0-auc:0.99995
# [2326]	validation_0-logloss:0.00836	validation_0-auc:0.99995
# [2327]	validation_0-logloss:0.00836	validation_0-auc:0.99995
# [2328]	validation_0-logloss:0.00837	validation_0-auc:0.99995
# [2329]	validation_0-logloss:0.00836	validation_0-auc:0.99995
# [2330]	validation_0-logloss:0.00836	validation_0-auc:0.99995
# [2331]	validation_0-logloss:0.00836	validation_0-auc:0.99995
# [2332]	validation_0-logloss:0.00836	validation_0-auc:0.99995
# [2333]	validation_0-logloss:0.00836	validation_0-auc:0.99995
# [2334]	validation_0-logloss:0.00837	validation_0-auc:0.99995
# [2335]	validation_0-logloss:0.00836	validation_0-auc:0.99995
# [2336]	validation_0-logloss:0.00837	validation_0-auc:0.99995
# [2337]	validation_0-logloss:0.00836	validation_0-auc:0.99995
# [2338]	validation_0-logloss:0.00836	validation_0-auc:0.99995
# [2339]	validation_0-logloss:0.00836	validation_0-auc:0.99995
# [2340]	validation_0-logloss:0.00836	validation_0-auc:0.99995
# [2341]	validation_0-logloss:0.00836	validation_0-auc:0.99995
# [2342]	validation_0-logloss:0.00836	validation_0-auc:0.99995
# [2343]	validation_0-logloss:0.00836	validation_0-auc:0.99995
# [2344]	validation_0-logloss:0.00836	validation_0-auc:0.99995
# [2345]	validation_0-logloss:0.00836	validation_0-auc:0.99995
# [2346]	validation_0-logloss:0.00836	validation_0-auc:0.99995
# [2347]	validation_0-logloss:0.00836	validation_0-auc:0.99995
# [2348]	validation_0-logloss:0.00836	validation_0-auc:0.99995
# [2349]	validation_0-logloss:0.00836	validation_0-auc:0.99995
# [2350]	validation_0-logloss:0.00836	validation_0-auc:0.99995
# [2351]	validation_0-logloss:0.00836	validation_0-auc:0.99995
# [2352]	validation_0-logloss:0.00836	validation_0-auc:0.99995
# [2353]	validation_0-logloss:0.00836	validation_0-auc:0.99995
# [2354]	validation_0-logloss:0.00836	validation_0-auc:0.99995
# [2355]	validation_0-logloss:0.00836	validation_0-auc:0.99995
# [2356]	validation_0-logloss:0.00836	validation_0-auc:0.99995
# [2357]	validation_0-logloss:0.00836	validation_0-auc:0.99995
# [2358]	validation_0-logloss:0.00836	validation_0-auc:0.99995
# [2359]	validation_0-logloss:0.00835	validation_0-auc:0.99995
# [2360]	validation_0-logloss:0.00835	validation_0-auc:0.99995
# [2361]	validation_0-logloss:0.00835	validation_0-auc:0.99995
# [2362]	validation_0-logloss:0.00835	validation_0-auc:0.99995
# [2363]	validation_0-logloss:0.00835	validation_0-auc:0.99995
# [2364]	validation_0-logloss:0.00835	validation_0-auc:0.99995
# [2365]	validation_0-logloss:0.00835	validation_0-auc:0.99995
# [2366]	validation_0-logloss:0.00836	validation_0-auc:0.99995
# [2367]	validation_0-logloss:0.00836	validation_0-auc:0.99995
# [2368]	validation_0-logloss:0.00835	validation_0-auc:0.99995
# [2369]	validation_0-logloss:0.00835	validation_0-auc:0.99995
# [2370]	validation_0-logloss:0.00835	validation_0-auc:0.99995
# [2371]	validation_0-logloss:0.00835	validation_0-auc:0.99995
# [2372]	validation_0-logloss:0.00835	validation_0-auc:0.99995
# [2373]	validation_0-logloss:0.00835	validation_0-auc:0.99995
# [2374]	validation_0-logloss:0.00835	validation_0-auc:0.99995
# [2375]	validation_0-logloss:0.00835	validation_0-auc:0.99995
# [2376]	validation_0-logloss:0.00835	validation_0-auc:0.99995
# [2377]	validation_0-logloss:0.00835	validation_0-auc:0.99995
# [2378]	validation_0-logloss:0.00835	validation_0-auc:0.99995
# [2379]	validation_0-logloss:0.00835	validation_0-auc:0.99995
# [2380]	validation_0-logloss:0.00835	validation_0-auc:0.99995
# [2381]	validation_0-logloss:0.00835	validation_0-auc:0.99995
# [2382]	validation_0-logloss:0.00835	validation_0-auc:0.99995
# [2383]	validation_0-logloss:0.00835	validation_0-auc:0.99995
# [2384]	validation_0-logloss:0.00835	validation_0-auc:0.99995
# [2385]	validation_0-logloss:0.00835	validation_0-auc:0.99995
# [2386]	validation_0-logloss:0.00835	validation_0-auc:0.99995
# [2387]	validation_0-logloss:0.00835	validation_0-auc:0.99995
# [2388]	validation_0-logloss:0.00835	validation_0-auc:0.99995
# [2389]	validation_0-logloss:0.00835	validation_0-auc:0.99995
# [2390]	validation_0-logloss:0.00835	validation_0-auc:0.99995
# [2391]	validation_0-logloss:0.00835	validation_0-auc:0.99995
# [2392]	validation_0-logloss:0.00835	validation_0-auc:0.99995
# [2393]	validation_0-logloss:0.00835	validation_0-auc:0.99995
# [2394]	validation_0-logloss:0.00835	validation_0-auc:0.99995
# [2395]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2396]	validation_0-logloss:0.00835	validation_0-auc:0.99995
# [2397]	validation_0-logloss:0.00835	validation_0-auc:0.99995
# [2398]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2399]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2400]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2401]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2402]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2403]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2404]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2405]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2406]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2407]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2408]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2409]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2410]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2411]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2412]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2413]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2414]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2415]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2416]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2417]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2418]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2419]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2420]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2421]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2422]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2423]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2424]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2425]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2426]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2427]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2428]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2429]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2430]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2431]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2432]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2433]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2434]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2435]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2436]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2437]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2438]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2439]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2440]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2441]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2442]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2443]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2444]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2445]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2446]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2447]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2448]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2449]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2450]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2451]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2452]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2453]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2454]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2455]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2456]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2457]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2458]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2459]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2460]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2461]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2462]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2463]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2464]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2465]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2466]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2467]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2468]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2469]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2470]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2471]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2472]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2473]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2474]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2475]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2476]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2477]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2478]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2479]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2480]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2481]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2482]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2483]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2484]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2485]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2486]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2487]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2488]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2489]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2490]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2491]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2492]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2493]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2494]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2495]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2496]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2497]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2498]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2499]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2500]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2501]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2502]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2503]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2504]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2505]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2506]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2507]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2508]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2509]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2510]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2511]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2512]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# [2513]	validation_0-logloss:0.00834	validation_0-auc:0.99995
# ◆ Early-stopped at round 2413
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric=['logloss', 'auc'],
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=2413,
#               n_jobs=None, num_parallel_tree=None, random_state=42, ...)

# %%
# -------------------------------------------------------
# 8. 평가 ----------------------------------------------
# -------------------------------------------------------
def evaluate(tag, yt, yp, prob):
    acc = accuracy_score(yt, yp)
    pr, re, f1, _ = precision_recall_fscore_support(yt, yp, average='binary', zero_division=0)
    auc = roc_auc_score(yt, prob)
    cm  = confusion_matrix(yt, yp)
    print(f'\n[{tag}] Acc:{acc:.4f} | Prec:{pr:.4f} | Rec:{re:.4f} | F1:{f1:.4f} | AUC:{auc:.4f}')
    print('Confusion Matrix:\n', cm)

evaluate('Validation(OOS)', y_val, model.predict(X_val), model.predict_proba(X_val)[:,1])
evaluate('Test',            y_test, model.predict(X_test), model.predict_proba(X_test)[:,1])
# Out:
# [Validation(OOS)] Acc:0.9994 | Prec:0.9993 | Rec:0.9998 | F1:0.9995 | AUC:1.0000
# Confusion Matrix:
#  [[156559    178]
#  [    53 244930]]
#
# [Test] Acc:0.9968 | Prec:0.9965 | Rec:0.9983 | F1:0.9974 | AUC:1.0000
# Confusion Matrix:
#  [[155867    870]
#  [   420 244563]]

# %%
# -------------------------------------------------------
# 9. 모델 & 메타데이터 저장 -----------------------------
# -------------------------------------------------------
today = datetime.date.today().isoformat()
model_path = os.path.join(MODEL_DIR, f'xgb_ais_zone_{today}.joblib')
joblib.dump(model, model_path)

with open(model_path.replace('.joblib', '.json'), 'w') as f:
    json.dump({
        'date'      : today,
        'train'     : len(X_train) + len(X_val),
        'test'      : len(X_test),
        'features'  : list(X.columns),
        'params'    : {k:v for k,v in base_params.items() if k!='early_stopping_rounds'},
        'best_iter' : int(best_iter)
    }, f, indent=2)

print(f'\n✅ 모델 저장 완료 → {model_path}')
# Out:
# ✅ 모델 저장 완료 → /content/drive/MyDrive/25년 해군 AI 경진대회/model_result/xgb_ais_zone_2025-05-28.joblib

# %%
import time, os, numpy as np, pandas as pd, geopandas as gpd, joblib
from shapely.geometry import Polygon, box
from xgboost import XGBClassifier

t0 = time.time()
print('1) 모델·경로 설정…')
MODEL_PATH = '/content/drive/MyDrive/25년 해군 AI 경진대회/model_result/xgb_ais_zone_2025-05-28.joblib'   # 수정
CSV_PATH   = '/content/drive/MyDrive/25년 해군 AI 경진대회/1번문제/20240701(1번문제).csv'
ZONE_DIR   = '/content/drive/MyDrive/25년 해군 AI 경진대회/dataset/구역 데이터'
OUT_PATH   = CSV_PATH.replace('.csv', '_with_result.csv')

# ---------- 1. 구역 로드 ----------
def load_zone_csv(path, label):
    df = pd.read_csv(path)
    lon = next(c for c in df.columns if c.lower()=='lon')
    lat = next(c for c in df.columns if c.lower()=='lat')
    grp = next((c for c in df.columns if c.lower().startswith('obj')), None)
    polys=[]
    for _, g in (df.groupby(grp) if grp else [('s', df)]):
        pts=list(zip(g[lon], g[lat]));  pts.append(pts[0])
        p=Polygon(pts)
        if p.is_valid and not p.is_empty: polys.append(p)
    return gpd.GeoDataFrame({'zone_type':[label]*len(polys), 'geometry':polys},
                            crs='EPSG:4326')

zones=[]
for f,lbl in [('Area_Navy_train.csv','navy_train'), ('Area_Near_Sea.csv','near_sea'),
              ('Area_Restrict_zone.csv','restrict'), ('Area_Sea_cable_lv1_poly.csv','sea_cable'),
              ('Area_Special_restrict_zone_poly.csv','special_restrict'),
              ('Area_Target_Area.csv','target_area')]:
    path = os.path.join(ZONE_DIR, f)
    print(f'  • {f}')
    zones.append(load_zone_csv(path, lbl))
zones_gdf = pd.concat(zones, ignore_index=True)
print('   → zones loaded:', len(zones_gdf), 'polygons\n')

# ---------- 2. CSV 로드 ----------
print('2) 1번 문제 CSV 로드…')
gdf = pd.read_csv(CSV_PATH)
print('   → rows:', len(gdf))

# ---------- 2-1. BBox ----------
print('3) Bounding-box 생성…')
bbox = [box(min(a,b), min(c,d), max(a,b), max(c,d))
        for a,b,c,d in zip(gdf['min_lon'], gdf['max_lon'],
                           gdf['min_lat'], gdf['max_lat'])]
gdf = gpd.GeoDataFrame(gdf, geometry=bbox, crs='EPSG:4326')

# ---------- 2-2. sjoin ----------
print('4) 공간 join… (잠시 소요)')
join = gpd.sjoin(gdf[['geometry']].reset_index(),
                 zones_gdf[['zone_type','geometry']],
                 how='left', predicate='intersects').rename(columns={'index':'idx'})
print('   → join rows:', len(join))

pivot = (join.dropna(subset=['zone_type'])
              .assign(hit=1)
              .pivot_table(index='idx', columns='zone_type',
                           values='hit', aggfunc='sum', fill_value=0))

gdf['num_zone_hits'] = pivot.sum(axis=1).reindex(gdf.index, fill_value=0).astype(int)
for z in zones_gdf['zone_type'].unique():
    gdf[f'in_{z}'] = ((pivot.get(z,0)>0)
                      .reindex(gdf.index, fill_value=0).astype(int))

# ---------- 2-3. 날짜 파생 ----------
print('5) 날짜 → 숫자 파생…')
for col in gdf.select_dtypes(include=['object']).columns:
    if col in ('MMSI','result'): continue
    try:
        dt = pd.to_datetime(gdf[col], errors='raise')
        gdf[f'{col}_doy'] = dt.dt.dayofyear
        gdf[f'{col}_dow'] = dt.dt.weekday
        gdf.drop(columns=[col], inplace=True)
    except: gdf.drop(columns=[col], inplace=True)

# ---------- 3. 모델 & feature 정합 ----------
print('6) 모델 로드 & feature 맞추기…')
model:XGBClassifier = joblib.load(MODEL_PATH)
model_feats = model.get_booster().feature_names
for f in model_feats:
    if f not in gdf.columns:
        gdf[f] = 0
X_input = gdf[model_feats]

# ---------- 4. 예측 ----------
print('7) 예측 실행…')
prob = model.predict_proba(X_input)[:,1]
gdf['result'] = np.where(prob>=0.5, 'True', 'False')

# ---------- 5. 저장 ----------
print('8) CSV 저장…')
gdf.drop(columns=['geometry']).to_csv(OUT_PATH, index=False, encoding='utf-8-sig')
print(f"✅ 완료! {OUT_PATH}")
print('총 소요: %.1f 초' % (time.time()-t0))
# Out:
# 1) 모델·경로 설정…
#   • Area_Navy_train.csv
#   • Area_Near_Sea.csv
#   • Area_Restrict_zone.csv
#   • Area_Sea_cable_lv1_poly.csv
#   • Area_Special_restrict_zone_poly.csv
#   • Area_Target_Area.csv
#    → zones loaded: 242 polygons
#
# 2) 1번 문제 CSV 로드…
#    → rows: 6779
# 3) Bounding-box 생성…
# 4) 공간 join… (잠시 소요)
#    → join rows: 42094
# 5) 날짜 → 숫자 파생…
# 6) 모델 로드 & feature 맞추기…
# 7) 예측 실행…
# 8) CSV 저장…
# ✅ 완료! /content/drive/MyDrive/25년 해군 AI 경진대회/1번문제/20240701(1번문제)_with_result.csv
# 총 소요: 0.8 초
